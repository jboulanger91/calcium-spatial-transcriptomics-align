# %% [markdown]
# # CircuitSeeker multimodal registration (clean)
#
# This notebook is a cleaned, end-to-end multimodal registration workflow using **CircuitSeeker**.
#
# ## Workflow
# 1. **Inputs & obvious corrections**
#    - Define a single global identifier: `run_id = "<exp_id>_fish<fish>"` for naming outputs
#    - Load fixed/moving TIFF stacks and convert axis order to **(X, Y, Z)**
#    - Pad **±20 µm** in Z (recommended)
#
# 2. **Foreground detection**
#    - Coarse brain masks for fixed and moving
#
# 3. **Moments initialization**
#    - Principal-axes alignment (`modes`)
#
# 4. **Global alignment**
#    - rigid → affine → deform (B-spline)
#
# 5. **Wiggle refinement**
#    - Nested piecewise alignment (runs locally via ClusterWrap `local_cluster`)
#
# 6. **Invert transforms + sanity check**
#    - Save inverse transforms and warp fixed → moving space
#
# ## Notes
# - **Axis order**: TIFF stacks are assumed **(Z, Y, X)** and are converted to **(X, Y, Z)** internally.
# - **Spacing units**: microns (µm), order **(X, Y, Z)**.
# - All outputs are written under `out_path` with the prefix: **`<exp_id>_fish<fish>_...`**

# %%
# Imports (clean)
from pathlib import Path
import json
import numpy as np
import nrrd

from tifffile import imread, imwrite
from scipy.ndimage import zoom, binary_closing, binary_dilation

from CircuitSeeker import level_set
from CircuitSeeker.axisalign import principal_axes, align_modes
from CircuitSeeker.align import alignment_pipeline, nested_distributed_piecewise_alignment_pipeline
from CircuitSeeker.transform import apply_transform, invert_displacement_vector_field
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# =====================
# Experiment parameters
# =====================

# Global identifiers used for ALL output names
exp_id = "exp_001"     # e.g. "001" or "exp1_110425"
fish = 2           # integer

run_id = f"{exp_id}_fish{fish}"

# Spacing (µm), order: (X, Y, Z)
mov_spacing = np.array([0.396, 0.396, 2.0], dtype=float)
fix_spacing = np.array([0.621, 0.621, 1.0], dtype=float)

# Wiggle random search iterations
randomiter = 25

# Z padding (physical units)
pad_um = 20.0

# =====================
# Paths (edit these)
# =====================

mov_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/2p_stacks/2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz_enh.tif"
)

fix_path = Path(
    "//Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/oct_confocal_stacks/fish2/prealigned/exp_001_fish2_s07_pre_GCaMP_cropped.tif"
)

out_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/CircuitSeeker_output"
)
out_path.mkdir(parents=True, exist_ok=True)

intermediates_path = out_path / "intermediates"
intermediates_path.mkdir(parents=True, exist_ok=True)

print("Fixed stack:\n", fix_path)
print("\nMoving stack:\n", mov_path)
print("\nOutput folder:\n", out_path)
# Out:
# Fixed stack:
#  //Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/oct_confocal_stacks/fish2/prealigned/exp_001_fish2_s07_pre_GCaMP_cropped.tif
#
# Moving stack:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/2p_stacks/2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz_enh.tif
#
# Output folder:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output

# %%
# =====================
# Helpers
# =====================

def save_path(tag: str, ext: str) -> Path:
    """Standard output path: <out_path>/<run_id>_<tag>.<ext>"""
    return out_path / f"{run_id}_{tag}.{ext}"

def write_meta(**kwargs):
    meta = dict(run_id=run_id, exp_id=exp_id, fish=int(fish), **kwargs)
    p = save_path("metadata", "json")
    with open(p, "w") as f:
        json.dump(meta, f, indent=2, sort_keys=True)
    print("[save]", p)

def to_xyz(vol_zyx: np.ndarray) -> np.ndarray:
    """Convert TIFF order (Z,Y,X) -> (X,Y,Z)."""
    if vol_zyx.ndim != 3:
        raise ValueError(f"Expected 3D TIFF stack (Z,Y,X). Got {vol_zyx.shape}")
    return vol_zyx.transpose(2, 1, 0)

def to_zyx(vol_xyz: np.ndarray) -> np.ndarray:
    """Convert (X,Y,Z) -> TIFF order (Z,Y,X)."""
    if vol_xyz.ndim != 3:
        raise ValueError(f"Expected 3D volume (X,Y,Z). Got {vol_xyz.shape}")
    return vol_xyz.transpose(2, 1, 0)

def pad_z_um(vol_xyz: np.ndarray, spacing_z_um: float, pad_um: float, fill=0):
    """Pad in Z by pad_um (µm) on each side. Volume is (X,Y,Z)."""
    n = int(np.round(float(pad_um) / float(spacing_z_um)))
    if n <= 0:
        return vol_xyz, 0
    vol_p = np.pad(vol_xyz, ((0, 0), (0, 0), (n, n)), mode="constant", constant_values=fill)
    return vol_p, n

def brain_mask(vol_xyz: np.ndarray, spacing_xyz: np.ndarray, lambda2: float):
    """Coarse brain mask via level_set on a downsampled volume, then upsample + smooth."""
    vol_skip = vol_xyz[::2, ::2, ::2]
    skip_spacing = spacing_xyz * np.array([2, 2, 2], dtype=float)

    mask_small = level_set.brain_detection(
        vol_skip, skip_spacing,
        mask_smoothing=2,
        iterations=[80, 40, 10],
        smooth_sigmas=[12, 6, 3],
        lambda2=lambda2,
    )

    mask = zoom(mask_small, np.array(vol_xyz.shape) / np.array(vol_skip.shape), order=0)
    mask = binary_closing(mask, np.ones((5, 5, 5))).astype(np.uint8)
    mask = binary_dilation(mask, np.ones((5, 5, 5))).astype(np.uint8)
    return mask

# %% [markdown]
# ## 1) Inputs and obvious corrections
#
# Load fixed and moving stacks, convert to **(X, Y, Z)**, and pad **±20 µm** in Z.
# Also saves padded TIFFs for QC.

# %%
# Load TIFFs (assumed Z,Y,X) -> convert to X,Y,Z
fix = to_xyz(imread(fix_path))
mov = to_xyz(imread(mov_path))

print("Original shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Pad in Z (±pad_um)
fix, fix_pad_slices = pad_z_um(fix, fix_spacing[2], pad_um, fill=0)
mov, mov_pad_slices = pad_z_um(mov, mov_spacing[2], pad_um, fill=0)

print(f"Padding applied: fix +/- {fix_pad_slices} slices, mov +/- {mov_pad_slices} slices")
print("Padded shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Save padded stacks (TIFF order Z,Y,X)
fix_padded_path = save_path("fixed_pad20um", "tif")
mov_padded_path = save_path("moving_pad20um", "tif")

imwrite(fix_padded_path, to_zyx(fix), bigtiff=True)
imwrite(mov_padded_path, to_zyx(mov), bigtiff=True)

print("[save] padded stacks:")
print("  fix:", fix_padded_path)
print("  mov:", mov_padded_path)

write_meta(
    fixed_path=str(fix_path),
    moving_path=str(mov_path),
    fix_spacing_um=list(map(float, fix_spacing)),
    mov_spacing_um=list(map(float, mov_spacing)),
    pad_um=float(pad_um),
    fix_pad_slices=int(fix_pad_slices),
    mov_pad_slices=int(mov_pad_slices),
)
# Out:
# Original shapes (X,Y,Z):
#   fix: (591, 744, 59)
#   mov: (799, 799, 56)
# Padding applied: fix +/- 20 slices, mov +/- 10 slices
# Padded shapes (X,Y,Z):
#   fix: (591, 744, 99)
#   mov: (799, 799, 76)
# [save] padded stacks:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fixed_pad20um.tif
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_moving_pad20um.tif
# [save] /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_metadata.json

# %% [markdown]
# ## 2) Foreground masks (fixed + moving)

# %%
import numpy as np
import nrrd
from scipy.ndimage import gaussian_filter, binary_fill_holes, binary_closing, binary_dilation
from skimage.filters import threshold_otsu
from skimage.measure import label

def otsu_fill_mask(vol, sigma=2, close_shape=(5,5,5), dilate_iter=64):
    # normalize
    v = vol.astype(np.float32)
    p1, p99 = np.percentile(v, (1, 99))
    v = np.clip((v - p1) / (p99 - p1 + 1e-6), 0, 1)

    # smooth
    v = gaussian_filter(v, sigma=sigma)

    # threshold
    t = threshold_otsu(v)
    m = v > t

    # keep largest CC (guard empty)
    lbl = label(m)
    if lbl.max() > 0:
        counts = np.bincount(lbl.ravel())
        counts[0] = 0
        m = lbl == counts.argmax()

    # fill + smooth + margin
    m = binary_fill_holes(m)
    m = binary_closing(m, structure=np.ones(close_shape, dtype=bool))
    m = binary_dilation(m, iterations=int(dilate_iter))

    return m.astype(np.uint8)

# --- FIX mask ---
fix_mask = otsu_fill_mask(fix, sigma=2, close_shape=(5,5,5), dilate_iter=64)
fix_mask_path = save_path("fix_mask", "nrrd")
nrrd.write(str(fix_mask_path), fix_mask)
print("  fix:", fix_mask_path)

# --- MOV mask (same strategy, homogeneous) ---
mov_mask = otsu_fill_mask(mov, sigma=2, close_shape=(5,5,5), dilate_iter=64)
mov_mask_path = save_path("mov_mask", "nrrd")
nrrd.write(str(mov_mask_path), mov_mask)
print("  mov:", mov_mask_path)
# Out:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fix_mask.nrrd
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_mov_mask.nrrd

# %% [markdown]
# ## 3) Moments initialization (modes)

# %%
fix_mean, fix_evals, fix_evecs = principal_axes(fix_mask, fix_spacing)
mov_mean, mov_evals, mov_evecs = principal_axes(mov_mask, mov_spacing)

modes = align_modes(fix_mean, fix_evecs, mov_mean, mov_evecs)

modes_aligned = apply_transform(
    fix, mov,
    fix_spacing, mov_spacing,
    transform_list=[modes],
)

np.savetxt(save_path("modes", "mat"), modes)
nrrd.write(str(save_path("modes_aligned", "nrrd")), modes_aligned, compression_level=2)

print("[save] modes:", save_path("modes", "mat"))
# Out:
# [save] modes: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_modes.mat

# %% [markdown]
# ## 4) Global alignment (rigid → affine → deform)

# %%
affine, deform = alignment_pipeline(
    fix, mov, fix_spacing, mov_spacing,
    steps=["rigid", "affine", "deform"],
    initial_transform=modes,
    alignment_spacing=2.0,
    shrink_factors=[2],
    smooth_sigmas=[8.0],
    iterations=400,
    deform_kwargs={
        "control_point_spacing": 12,
        "control_point_levels": [1, 2, 4, 8],
    },
)

# alignment_pipeline returns (affine, (params, field))
deform_field = deform[1]

affine_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine])
deform_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine, deform_field])

np.savetxt(save_path("affine", "mat"), affine)
nrrd.write(str(save_path("deform", "nrrd")), deform_field, compression_level=2)
nrrd.write(str(save_path("affine_aligned", "nrrd")), affine_aligned, compression_level=2)
nrrd.write(str(save_path("deform_aligned", "nrrd")), deform_aligned, compression_level=2)

print("[save] global alignment outputs under:", out_path)
# Out:
# LEVEL:  0  ITERATION:  0  METRIC:  -0.04848661139718186
# LEVEL:  0  ITERATION:  1  METRIC:  -0.04868713958527164
# LEVEL:  0  ITERATION:  2  METRIC:  -0.048891809470238426
# LEVEL:  0  ITERATION:  3  METRIC:  -0.04880637564284754
# LEVEL:  0  ITERATION:  4  METRIC:  -0.04912930501839995
# LEVEL:  0  ITERATION:  5  METRIC:  -0.049733476753349895
# LEVEL:  0  ITERATION:  6  METRIC:  -0.0500921453855435
# LEVEL:  0  ITERATION:  7  METRIC:  -0.05034224505277744
# LEVEL:  0  ITERATION:  8  METRIC:  -0.0509000858783581
# LEVEL:  0  ITERATION:  9  METRIC:  -0.05198946534667429
# LEVEL:  0  ITERATION:  10  METRIC:  -0.052544830277478735
# LEVEL:  0  ITERATION:  11  METRIC:  -0.05374610134108611
# LEVEL:  0  ITERATION:  12  METRIC:  -0.055390614381189335
# LEVEL:  0  ITERATION:  13  METRIC:  -0.05701381692049642
# LEVEL:  0  ITERATION:  14  METRIC:  -0.0585094307399683
# LEVEL:  0  ITERATION:  15  METRIC:  -0.060822197832446086
# LEVEL:  0  ITERATION:  16  METRIC:  -0.06349120196180597
# LEVEL:  0  ITERATION:  17  METRIC:  -0.06711185270653941
# LEVEL:  0  ITERATION:  18  METRIC:  -0.07040610166201539
# LEVEL:  0  ITERATION:  19  METRIC:  -0.0750370430051374
# LEVEL:  0  ITERATION:  20  METRIC:  -0.07880894759376021
# LEVEL:  0  ITERATION:  21  METRIC:  -0.08195110043263916
# LEVEL:  0  ITERATION:  22  METRIC:  -0.08417729398511278
# LEVEL:  0  ITERATION:  23  METRIC:  -0.08587893498652377
# LEVEL:  0  ITERATION:  24  METRIC:  -0.0872344305426262
# LEVEL:  0  ITERATION:  25  METRIC:  -0.08834023047801332
# LEVEL:  0  ITERATION:  26  METRIC:  -0.09075527227578788
# LEVEL:  0  ITERATION:  27  METRIC:  -0.09306476267417471
# LEVEL:  0  ITERATION:  28  METRIC:  -0.09525800736401988
# LEVEL:  0  ITERATION:  29  METRIC:  -0.09860885708446784
# LEVEL:  0  ITERATION:  30  METRIC:  -0.1018697834774599
# LEVEL:  0  ITERATION:  31  METRIC:  -0.10810245002431987
# LEVEL:  0  ITERATION:  32  METRIC:  -0.11049962485102698
# LEVEL:  0  ITERATION:  33  METRIC:  -0.11419969213367914
# LEVEL:  0  ITERATION:  97  METRIC:  -0.26935422165710365
# LEVEL:  0  ITERATION:  98  METRIC:  -0.2702271003135643
# LEVEL:  0  ITERATION:  99  METRIC:  -0.2712389932604898
# LEVEL:  0  ITERATION:  100  METRIC:  -0.2721993149324358
# LEVEL:  0  ITERATION:  101  METRIC:  -0.2731325198002559
# LEVEL:  0  ITERATION:  102  METRIC:  -0.2742395044165355
# LEVEL:  0  ITERATION:  103  METRIC:  -0.2752218889973673
# LEVEL:  0  ITERATION:  104  METRIC:  -0.2762542515783264
# LEVEL:  0  ITERATION:  105  METRIC:  -0.2771831734900857
# LEVEL:  0  ITERATION:  106  METRIC:  -0.27816387169654244
# LEVEL:  0  ITERATION:  107  METRIC:  -0.279071032773293
# LEVEL:  0  ITERATION:  108  METRIC:  -0.28014512482322523
# LEVEL:  0  ITERATION:  109  METRIC:  -0.2810875907793966
# LEVEL:  0  ITERATION:  110  METRIC:  -0.2821676874513624
# LEVEL:  0  ITERATION:  111  METRIC:  -0.28314581605726746
# LEVEL:  0  ITERATION:  112  METRIC:  -0.2842243529385199
# LEVEL:  0  ITERATION:  113  METRIC:  -0.2850450622604001
# LEVEL:  0  ITERATION:  114  METRIC:  -0.286018561341533
# LEVEL:  0  ITERATION:  115  METRIC:  -0.28699560205417984
# LEVEL:  0  ITERATION:  116  METRIC:  -0.28797635417623435
# LEVEL:  0  ITERATION:  117  METRIC:  -0.28902745163509397
# LEVEL:  0  ITERATION:  118  METRIC:  -0.28995226858474044
# LEVEL:  0  ITERATION:  119  METRIC:  -0.29092989456509005
# LEVEL:  0  ITERATION:  120  METRIC:  -0.29195741182192825
# LEVEL:  0  ITERATION:  121  METRIC:  -0.29281811188718504
# LEVEL:  0  ITERATION:  122  METRIC:  -0.29360076635964266
# LEVEL:  0  ITERATION:  123  METRIC:  -0.2946350739699858
# LEVEL:  0  ITERATION:  124  METRIC:  -0.29554459292149066
# LEVEL:  0  ITERATION:  125  METRIC:  -0.29651518446360603
# LEVEL:  0  ITERATION:  126  METRIC:  -0.2974384201852019
# LEVEL:  0  ITERATION:  127  METRIC:  -0.29835195832433314
# LEVEL:  0  ITERATION:  128  METRIC:  -0.2992760515556688
# LEVEL:  0  ITERATION:  129  METRIC:  -0.3002832959668943
# LEVEL:  0  ITERATION:  130  METRIC:  -0.3012780002328692
# LEVEL:  0  ITERATION:  131  METRIC:  -0.30218548518470695
# LEVEL:  0  ITERATION:  132  METRIC:  -0.30309409766785944
# LEVEL:  0  ITERATION:  133  METRIC:  -0.3039219207792018
# LEVEL:  0  ITERATION:  134  METRIC:  -0.30503795379632637
# LEVEL:  0  ITERATION:  135  METRIC:  -0.30600078802006364
# LEVEL:  0  ITERATION:  136  METRIC:  -0.30689389403273437
# LEVEL:  0  ITERATION:  137  METRIC:  -0.30791053160409226
# LEVEL:  0  ITERATION:  138  METRIC:  -0.3090081030219644
# LEVEL:  0  ITERATION:  139  METRIC:  -0.3100140968820568
# LEVEL:  0  ITERATION:  184  METRIC:  -0.3560003674370313
# LEVEL:  0  ITERATION:  185  METRIC:  -0.3569676112628478
# LEVEL:  0  ITERATION:  186  METRIC:  -0.3577142628380132
# LEVEL:  0  ITERATION:  187  METRIC:  -0.3585269808192855
# LEVEL:  0  ITERATION:  188  METRIC:  -0.35939285170390256
# LEVEL:  0  ITERATION:  189  METRIC:  -0.36005484144556715
# LEVEL:  0  ITERATION:  190  METRIC:  -0.36091317661617756
# LEVEL:  0  ITERATION:  191  METRIC:  -0.3615402461749615
# LEVEL:  0  ITERATION:  192  METRIC:  -0.3623002605253633
# LEVEL:  0  ITERATION:  193  METRIC:  -0.36293721626141445
# LEVEL:  0  ITERATION:  194  METRIC:  -0.3635425697997631
# LEVEL:  0  ITERATION:  195  METRIC:  -0.3639623463862171
# LEVEL:  0  ITERATION:  196  METRIC:  -0.36511891241367256
# LEVEL:  0  ITERATION:  197  METRIC:  -0.365287670780856
# LEVEL:  0  ITERATION:  198  METRIC:  -0.3667273621588186
# LEVEL:  0  ITERATION:  199  METRIC:  -0.3668295906739017
# LEVEL:  0  ITERATION:  200  METRIC:  -0.3683600002525288
# LEVEL:  0  ITERATION:  201  METRIC:  -0.3682517946024749
# LEVEL:  0  ITERATION:  202  METRIC:  -0.3704189625317423
# LEVEL:  0  ITERATION:  203  METRIC:  -0.3703457153359287
# LEVEL:  0  ITERATION:  204  METRIC:  -0.3721579362905945
# LEVEL:  0  ITERATION:  205  METRIC:  -0.37175353354797147
# LEVEL:  0  ITERATION:  206  METRIC:  -0.3734959105266314
# LEVEL:  0  ITERATION:  207  METRIC:  -0.3727937993233553
# LEVEL:  0  ITERATION:  208  METRIC:  -0.37535286482649793
# LEVEL:  0  ITERATION:  209  METRIC:  -0.3747462685294163
# LEVEL:  0  ITERATION:  210  METRIC:  -0.37732219399609523
# LEVEL:  0  ITERATION:  211  METRIC:  -0.3767646992578415
# LEVEL:  0  ITERATION:  212  METRIC:  -0.37913861325329373
# LEVEL:  0  ITERATION:  213  METRIC:  -0.3784896564518514
# LEVEL:  0  ITERATION:  214  METRIC:  -0.3813448043555231
# LEVEL:  0  ITERATION:  215  METRIC:  -0.38100366956481657
# LEVEL:  0  ITERATION:  216  METRIC:  -0.38311499736507637
# LEVEL:  0  ITERATION:  217  METRIC:  -0.3828901720978456
# LEVEL:  0  ITERATION:  218  METRIC:  -0.3844837491894211
# LEVEL:  0  ITERATION:  219  METRIC:  -0.38383546376349426
# LEVEL:  0  ITERATION:  220  METRIC:  -0.3851725693585653
# LEVEL:  0  ITERATION:  221  METRIC:  -0.38370375656556976
# LEVEL:  0  ITERATION:  222  METRIC:  -0.38601541336356127
# LEVEL:  0  ITERATION:  223  METRIC:  -0.3838578062277293
# LEVEL:  0  ITERATION:  224  METRIC:  -0.3870644442322476
# LEVEL:  0  ITERATION:  225  METRIC:  -0.3846913550570477
# LEVEL:  0  ITERATION:  226  METRIC:  -0.38888217943302344
# LEVEL:  0  ITERATION:  227  METRIC:  -0.38652765794154825
# LEVEL:  0  ITERATION:  228  METRIC:  -0.38989333610382787
# LEVEL:  0  ITERATION:  229  METRIC:  -0.38725807437051557
# LEVEL:  0  ITERATION:  230  METRIC:  -0.39155771740769757
# LEVEL:  0  ITERATION:  231  METRIC:  -0.38847524939929196
# LEVEL:  0  ITERATION:  232  METRIC:  -0.39320311458780005
# LEVEL:  0  ITERATION:  233  METRIC:  -0.3892993294551278
# LEVEL:  0  ITERATION:  234  METRIC:  -0.39491802267090254
# LEVEL:  0  ITERATION:  235  METRIC:  -0.3903645202203506
# LEVEL:  0  ITERATION:  236  METRIC:  -0.39648134593776446
# LEVEL:  0  ITERATION:  237  METRIC:  -0.3916227541340006
# LEVEL:  0  ITERATION:  238  METRIC:  -0.3974579911498353
# LEVEL:  0  ITERATION:  239  METRIC:  -0.39228835472124785
# LEVEL:  0  ITERATION:  240  METRIC:  -0.3986823895971396
# LEVEL:  0  ITERATION:  241  METRIC:  -0.39332049300855765
# LEVEL:  0  ITERATION:  242  METRIC:  -0.4000453837859973
# LEVEL:  0  ITERATION:  243  METRIC:  -0.3942478287847842
# LEVEL:  0  ITERATION:  244  METRIC:  -0.4018351245590759
# LEVEL:  0  ITERATION:  245  METRIC:  -0.39590509189740997
# LEVEL:  0  ITERATION:  246  METRIC:  -0.4030016368338534
# LEVEL:  0  ITERATION:  247  METRIC:  -0.3967188679274101
# LEVEL:  0  ITERATION:  248  METRIC:  -0.4042575608631208
# LEVEL:  0  ITERATION:  249  METRIC:  -0.39805792575392446
# LEVEL:  0  ITERATION:  250  METRIC:  -0.40567289542133045
# LEVEL:  0  ITERATION:  251  METRIC:  -0.3992658301535829
# LEVEL:  0  ITERATION:  252  METRIC:  -0.40713591325562537
# LEVEL:  0  ITERATION:  253  METRIC:  -0.4005764048194101
# LEVEL:  0  ITERATION:  254  METRIC:  -0.4082898360002909
# LEVEL:  0  ITERATION:  255  METRIC:  -0.4014515538022499
# LEVEL:  0  ITERATION:  256  METRIC:  -0.4097596867969687
# LEVEL:  0  ITERATION:  257  METRIC:  -0.40366113054969055
# LEVEL:  0  ITERATION:  258  METRIC:  -0.4107626404148297
# LEVEL:  0  ITERATION:  259  METRIC:  -0.40424054967807455
# LEVEL:  0  ITERATION:  260  METRIC:  -0.41262917993695253
# LEVEL:  0  ITERATION:  261  METRIC:  -0.4064678185088762
# LEVEL:  0  ITERATION:  262  METRIC:  -0.4135901551033014
# LEVEL:  0  ITERATION:  263  METRIC:  -0.4070850930017869
# LEVEL:  0  ITERATION:  264  METRIC:  -0.4159658459001985
# LEVEL:  0  ITERATION:  265  METRIC:  -0.41023893782204757
# LEVEL:  0  ITERATION:  266  METRIC:  -0.4162916555648463
# LEVEL:  0  ITERATION:  267  METRIC:  -0.4095544267148399
# LEVEL:  0  ITERATION:  268  METRIC:  -0.41838260729970606
# LEVEL:  0  ITERATION:  269  METRIC:  -0.4118450408899095
# LEVEL:  0  ITERATION:  270  METRIC:  -0.4191934544810202
# LEVEL:  0  ITERATION:  271  METRIC:  -0.4122212245018189
# LEVEL:  0  ITERATION:  272  METRIC:  -0.4203490950687142
# LEVEL:  0  ITERATION:  273  METRIC:  -0.4132210428426575
# LEVEL:  0  ITERATION:  274  METRIC:  -0.42156135551880336
# LEVEL:  0  ITERATION:  275  METRIC:  -0.4144833453562953
# LEVEL:  0  ITERATION:  276  METRIC:  -0.4228656138905771
# LEVEL:  0  ITERATION:  277  METRIC:  -0.4157670674513217
# LEVEL:  0  ITERATION:  278  METRIC:  -0.42411480948283214
# LEVEL:  0  ITERATION:  279  METRIC:  -0.4168770815361642
# LEVEL:  0  ITERATION:  280  METRIC:  -0.42557376907253486
# LEVEL:  0  ITERATION:  281  METRIC:  -0.41823129059895037
# LEVEL:  0  ITERATION:  282  METRIC:  -0.4268520402992129
# LEVEL:  0  ITERATION:  283  METRIC:  -0.4192818078263636
# LEVEL:  0  ITERATION:  284  METRIC:  -0.4282209310215022
# LEVEL:  0  ITERATION:  285  METRIC:  -0.4204757821631787
# LEVEL:  0  ITERATION:  286  METRIC:  -0.42969383085152296
# LEVEL:  0  ITERATION:  287  METRIC:  -0.4216757153523424
# LEVEL:  0  ITERATION:  288  METRIC:  -0.43079530805244176
# LEVEL:  0  ITERATION:  289  METRIC:  -0.422836217285426
# LEVEL:  0  ITERATION:  290  METRIC:  -0.4318369895718728
# LEVEL:  0  ITERATION:  291  METRIC:  -0.4237656850683138
# LEVEL:  0  ITERATION:  292  METRIC:  -0.43286173402533906
# LEVEL:  0  ITERATION:  293  METRIC:  -0.42414824652065525
# LEVEL:  0  ITERATION:  294  METRIC:  -0.4336981407792146
# LEVEL:  0  ITERATION:  295  METRIC:  -0.42450822259078824
# LEVEL:  0  ITERATION:  296  METRIC:  -0.4349981537733285
# LEVEL:  0  ITERATION:  297  METRIC:  -0.42588103593467286
# LEVEL:  0  ITERATION:  298  METRIC:  -0.4357841519889403
# LEVEL:  0  ITERATION:  299  METRIC:  -0.42686336141895187
# LEVEL:  0  ITERATION:  300  METRIC:  -0.43689781347276396
# LEVEL:  0  ITERATION:  301  METRIC:  -0.42840399200437485
# LEVEL:  0  ITERATION:  302  METRIC:  -0.43808366537152665
# LEVEL:  0  ITERATION:  303  METRIC:  -0.4298074026597159
# LEVEL:  0  ITERATION:  304  METRIC:  -0.43842833020590666
# LEVEL:  0  ITERATION:  305  METRIC:  -0.43075877743093266
# LEVEL:  0  ITERATION:  306  METRIC:  -0.43775123463227045
# LEVEL:  0  ITERATION:  307  METRIC:  -0.43295675509221154
# LEVEL:  0  ITERATION:  308  METRIC:  -0.4350669996602549
# [save] global alignment outputs under: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output

# %% [markdown]
# ## 5) Wiggle refinement (nested piecewise alignment)

# %%
block_schedule = [[tuple(np.maximum(1, np.round(np.array(fix.shape) / 32).astype(int)))]]

parameter_schedule = [
        {'random_kwargs':{'max_translation':2.,
                        'max_rotation':2. * np.pi/180.,
                        'max_scale':1.02,
                        'max_shear':.02,
                        'random_iterations':randomiter,
                        'affine_align_best':10,
                        'iterations':24,},
        'affine_kwargs':{},
        'deform_kwargs':{},
        },
    ]
# run twist
wiggle = nested_distributed_piecewise_alignment_pipeline(
    fix,
    mov,
    fix_spacing,
    mov_spacing,
    block_schedule,
    parameter_schedule=parameter_schedule,
    initial_transform_list=[affine, deform_field],
    fix_mask=fix_mask,
    mov_mask=mov_mask,
    steps=['random', 'affine'],
    bins=32,
    shrink_factors=[1,],
    smooth_sigmas=[6.0,],
    iterations=400,
    learning_rate=0.1,
    max_step=0.1,
    estimate_learning_rate='never',
    callback=lambda irm: None,
    intermediates_path=str(intermediates_path),
    cluster_kwargs={"cluster_type": "local_cluster", "n_workers": 6}
)

wiggled = apply_transform(
    fix, mov, fix_spacing, mov_spacing,
    transform_list=[affine, deform_field, wiggle],
)

nrrd.write(str(save_path("wiggle", "nrrd")), wiggle, compression_level=2)
nrrd.write(str(save_path("wiggled_aligned", "nrrd")), wiggled, compression_level=2)

print("[save] wiggle outputs:")
print("  wiggle:", save_path("wiggle", "nrrd"))
print("  wiggled:", save_path("wiggled_aligned", "nrrd"))
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa31ce78e00): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa2de4ee980): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa73e8da700): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa73e8c4ed0): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
#
# Returning default
# /Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 26.08 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# Optimization failed to improve metric
# initial value: -0.030820800434633897
# final value: -0.03066197411011672
# Returning default
# Optimization failed to improve metric
# initial value: -0.02945858755907592
# final value: -0.0292216266911429
# Returning default
# Optimization failed to improve metric
# initial value: -0.028748397322861618
# final value: -0.028149152061151407
# Returning default
# Optimization failed to improve metric
# initial value: -0.04204164287649001
# final value: -0.041757008670930615
# Returning default
# Optimization failed to improve metric
# initial value: -0.0355222395391013
# final value: -0.03542823267844743
# Returning default
# Optimization failed to improve metric
# initial value: -0.028434204282098082
# final value: -0.028272129469292886
# Returning default
# Optimization failed to improve metric
# initial value: -0.035180387411057966
# final value: -0.03512153762925959
# Returning default
# Optimization failed to improve metric
# initial value: -0.03432471856062449
# final value: -0.034159427035132105
# Returning default
# Optimization failed to improve metric
# initial value: -0.027915270424653076
# final value: -0.027642041735689897
# Returning default
# Optimization failed to improve metric
# initial value: -0.02732422924018771
# final value: -0.02714833215872081
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f8806fb1240): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fdd3fcb6840): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9816e27e90): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcca2e0f80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdd4efbd400): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef0814f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f97f1bb94e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f985c8f9ae0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9816e59390): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f793224c5d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79824392e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f793224c5d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79a28c3290): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef0b8070): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcca1fe220): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eabf71680): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f793203f4c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcfef8da10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef0b8070): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9ee6e44d80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87a7186930): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f984bfb5170): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f8bfb5090): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b73105e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f984bfb5170): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eabf6a100): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef055cb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcfef8da10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87a6f59f40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7932044780): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eabf6a320): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f8806ff6650): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7a2efe6600): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f8776f23520): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7a2efbcd40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f1cc6f210): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f984bfc9c90): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b71dd5c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79bf01ddc0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f794cf19910): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef05a070): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79824392e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef083a90): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f794ce17e00): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79e9e26390): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9816e74330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcfefbafb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79bf81e750): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79322626d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f984bfcd570): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7982067bc0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eac205910): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef0814f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcca2f3350): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f798244ded0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79820987b0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f8776f0e130): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eac02f220): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef084960): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9efc029c80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef084960): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b7316f30): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7a0f204e40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f1c910970): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f8776f0e130): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f97f1ba0c90): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [7.35714, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f982bf783c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9eabf6fc70): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b71dd5c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f97f1ba0c90): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [7.35714, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f794cf1f0d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79a28b8b40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79bf82b400): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9efc02ea50): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcfef8da10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdc9ef11370): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f8777f14320): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79e9e2b980): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b6fae510): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f97f1bdd870): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [7.35714, -2.43059e+37]
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.017900409387519564
# final value: -0.017839355793407428
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79820921b0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79c28c60b0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef025290): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7a0f463130): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdcef51ff70): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.025146633805780774
# final value: -0.02510377243750222
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7932751eb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdc9ef0e470): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f97f1c6f2d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9816e79950): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b719d610): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b719d610): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f794cf52940): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79bf036730): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f79a28d7fc0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f88478a1ed0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f87b6ff5f80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f8cb975e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdd3fad5be0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f7a9f9d8b00): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f98ac8e0500): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f8cbe0aa0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fdd3faa3d10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.43059e+37, -2.43059e+37]
#
# Returning default
# ...
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9d8bf43880): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f78cf18ac70): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.0110729427420752
# final value: -0.010816674003027688
# Returning default
# Optimization failed to improve metric
# initial value: -0.014891637337687584
# final value: -0.014868166838026196
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fdbfffab6f0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.0233861127273897
# final value: -0.02335805333722083
# Returning default
# Optimization failed to improve metric
# initial value: -0.011013422906102945
# final value: -0.010784530287713773
# Returning default
# Optimization failed to improve metric
# initial value: -0.03276254000883182
# final value: -0.03222917050238253
# Returning default
# Optimization failed to improve metric
# initial value: -0.0379840099495083
# final value: -0.037780751137114744
# Returning default
# Optimization failed to improve metric
# initial value: -0.010796253027602652
# final value: -0.010575781628872866
# Returning default
# Optimization failed to improve metric
# initial value: -0.05722666285073372
# final value: -0.05710994018929417
# Returning default
# Optimization failed to improve metric
# initial value: -0.025463762859569482
# final value: -0.025065847339856905
# Returning default
# Optimization failed to improve metric
# initial value: -0.021290344355299577
# final value: -0.02091798716012566
# Returning default
# Optimization failed to improve metric
# initial value: -0.010255933877919324
# final value: -0.010159345088416172
# Returning default
# Optimization failed to improve metric
# initial value: -0.019476743188526952
# final value: -0.019134159921204565
# Returning default
# Optimization failed to improve metric
# initial value: -0.04454744373106478
# final value: -0.0434798113497238
# Returning default
# Optimization failed to improve metric
# initial value: -0.013931292010489128
# final value: -0.01390014039066331
# Returning default
# Optimization failed to improve metric
# initial value: -0.020451236396877997
# final value: -0.02018616723839636
# Returning default
# Optimization failed to improve metric
# initial value: -0.04045107929562784
# final value: -0.03695797760714511
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9dcbf82b30): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.04420035964929749
# final value: -0.04337627642787149
# Returning default
# Optimization failed to improve metric
# initial value: -0.013795390164579504
# final value: -0.013773647732282793
# Returning default
# Optimization failed to improve metric
# initial value: -0.0171298392551124
# final value: -0.01696633580510304
# Returning default
# Optimization failed to improve metric
# initial value: -0.02090848314571115
# final value: -0.02089834656577186
# Returning default
# Optimization failed to improve metric
# initial value: -0.04407105292898521
# final value: -0.04381817511984333
# Returning default
# Optimization failed to improve metric
# initial value: -0.01759419937844425
# final value: -0.017573468961512993
# Returning default
# Optimization failed to improve metric
# initial value: -0.016776712758577676
# final value: -0.016595418677563818
# Returning default
# Optimization failed to improve metric
# initial value: -0.015430441960660155
# final value: -0.015405486941293445
# Returning default
# Optimization failed to improve metric
# initial value: -0.03533494464453785
# final value: -0.035119070222676955
# Returning default
# Optimization failed to improve metric
# initial value: -0.03822663174456581
# final value: -0.034915211035647445
# Returning default
# Optimization failed to improve metricOptimization failed to improve metric
# initial value: -0.015525802307196686
# final value: -0.015334391795041096
# Returning default
#
# initial value: -0.04156437462873367
# final value: -0.04057393854607039
# Returning default
# Optimization failed to improve metric
# initial value: -0.034629000464776225
# final value: -0.034585212612634635
# Returning default
# Optimization failed to improve metric
# initial value: -0.028533653271031526
# final value: -0.026023778138123448
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f78fefd0690): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.04141378528002352
# final value: -0.04135400946055216
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f87b72b9a90): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.03443345453834881
# final value: -0.03436797273134813
# Returning default
# Optimization failed to improve metric
# initial value: -0.017395526376244964
# final value: -0.017384143190062488
# Returning default
# Optimization failed to improve metric
# initial value: -0.014871772775690604
# final value: -0.014741844708863954
# Returning default
# Optimization failed to improve metric
# initial value: -0.034346071556384125
# final value: -0.034249203986008406
# Returning default
# Optimization failed to improve metric
# initial value: -0.033473352812043444
# final value: -0.030400846391513477
# Returning default
# Optimization failed to improve metric
# initial value: -0.07113290002052676
# final value: -0.07065488909870771
# Returning default
# Optimization failed to improve metric
# initial value: -0.014571462875478726
# final value: -0.014564425990142786
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f7851f7ef40): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.0340284316617536
# final value: -0.03381195125964282
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9f1caca640): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.014528018232810344
# final value: -0.014305957436682872
# Returning default
# Optimization failed to improve metric
# initial value: -0.026135520253391137
# final value: -0.026054117906803315
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fdcef4b7fd0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f7852061410): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.014504264268789455
# final value: -0.014389380324939544
# Returning default
# Optimization failed to improve metric
# initial value: -0.03927022633928305
# final value: -0.03922403771034566
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f79822e0920): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.03875613663303509
# final value: -0.03796962688419803
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f869704e770): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.0379840099495083
# final value: -0.036887220923354086
# Returning default
# Optimization failed to improve metric
# initial value: -0.03276254000883182
# final value: -0.02003594640468887
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fdbfffb7720): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f78cf347060): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.021290344355299577
# final value: -0.01594351085441972
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f8696f5d400): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f982c0cfbc0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.04454744373106478
# final value: -0.03381295956718753
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f982c3c39b0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# [save] wiggle outputs:
#   wiggle: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_wiggle.nrrd
#   wiggled: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_wiggled_aligned.nrrd

# %% [markdown]
# ## 6) Invert transforms + sanity check

# %%
affine_inv = np.linalg.inv(affine)
np.savetxt(save_path("affine_inv", "mat"), affine_inv)

deform_inv = invert_displacement_vector_field(deform_field, fix_spacing)
nrrd.write(str(save_path("deform_inv", "nrrd")), deform_inv, compression_level=2)

wiggle_inv = invert_displacement_vector_field(wiggle, fix_spacing)
nrrd.write(str(save_path("wiggle_inv", "nrrd")), wiggle_inv, compression_level=2)

# sanity check: warp fixed -> moving space
fix_to_mov = apply_transform(
    mov, fix, mov_spacing, fix_spacing,
    transform_list=[wiggle_inv, deform_inv, affine_inv],
    transform_spacing=fix_spacing,
)
nrrd.write(str(save_path("fix_warped_to_moving", "nrrd")), fix_to_mov, compression_level=2)

print("[save] inverse transforms + sanity warp written under:", out_path)
