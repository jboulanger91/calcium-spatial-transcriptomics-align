# %% [markdown]
# # CircuitSeeker multimodal registration (clean)
#
# This notebook is a cleaned, end-to-end multimodal registration workflow using **CircuitSeeker**.
#
# ## Workflow
# 1. **Inputs & obvious corrections**
#    - Define a single global identifier: `run_id = "<exp_id>_fish<fish>"` for naming outputs
#    - Load fixed/moving TIFF stacks and convert axis order to **(X, Y, Z)**
#    - Pad **±20 µm** in Z (recommended)
#
# 2. **Foreground detection**
#    - Coarse brain masks for fixed and moving
#
# 3. **Moments initialization**
#    - Principal-axes alignment (`modes`)
#
# 4. **Global alignment**
#    - rigid → affine → deform (B-spline)
#
# 5. **Wiggle refinement**
#    - Nested piecewise alignment (runs locally via ClusterWrap `local_cluster`)
#
# 6. **Invert transforms + sanity check**
#    - Save inverse transforms and warp fixed → moving space
#
# ## Notes
# - **Axis order**: TIFF stacks are assumed **(Z, Y, X)** and are converted to **(X, Y, Z)** internally.
# - **Spacing units**: microns (µm), order **(X, Y, Z)**.
# - All outputs are written under `out_path` with the prefix: **`<exp_id>_fish<fish>_...`**

# %%
# Imports (clean)
from pathlib import Path
import json
import numpy as np
import nrrd

from tifffile import imread, imwrite
from scipy.ndimage import zoom, binary_closing, binary_dilation

from CircuitSeeker import level_set
from CircuitSeeker.axisalign import principal_axes, align_modes
from CircuitSeeker.align import alignment_pipeline, nested_distributed_piecewise_alignment_pipeline
from CircuitSeeker.transform import apply_transform, invert_displacement_vector_field
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# =====================
# Experiment parameters
# =====================

# Global identifiers used for ALL output names
exp_id = "exp_001"     # e.g. "001" or "exp1_110425"
fish = 2           # integer

run_id = f"{exp_id}_fish{fish}"

# Spacing (µm), order: (X, Y, Z)
mov_spacing = np.array([0.396, 0.396, 2.0], dtype=float)
fix_spacing = np.array([0.621, 0.621, 1.0], dtype=float)

# Wiggle random search iterations
randomiter = 25

# Z padding (physical units)
pad_um = 20.0

# =====================
# Paths (edit these)
# =====================

mov_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/2p_stacks/2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz_enh.tif"
)

fix_path = Path(
    "//Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/oct_confocal_stacks/fish2/prealigned/exp_001_fish2_s07_pre_GCaMP_cropped.tif"
)

out_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/CircuitSeeker_output"
)
out_path.mkdir(parents=True, exist_ok=True)

intermediates_path = out_path / "intermediates"
intermediates_path.mkdir(parents=True, exist_ok=True)

print("Fixed stack:\n", fix_path)
print("\nMoving stack:\n", mov_path)
print("\nOutput folder:\n", out_path)
# Out:
# Fixed stack:
#  //Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/oct_confocal_stacks/fish2/prealigned/exp_001_fish2_s07_pre_GCaMP_cropped.tif
#
# Moving stack:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/2p_stacks/2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz_enh.tif
#
# Output folder:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output

# %%
# =====================
# Helpers
# =====================

def save_path(tag: str, ext: str) -> Path:
    """Standard output path: <out_path>/<run_id>_<tag>.<ext>"""
    return out_path / f"{run_id}_{tag}.{ext}"

def write_meta(**kwargs):
    meta = dict(run_id=run_id, exp_id=exp_id, fish=int(fish), **kwargs)
    p = save_path("metadata", "json")
    with open(p, "w") as f:
        json.dump(meta, f, indent=2, sort_keys=True)
    print("[save]", p)

def to_xyz(vol_zyx: np.ndarray) -> np.ndarray:
    """Convert TIFF order (Z,Y,X) -> (X,Y,Z)."""
    if vol_zyx.ndim != 3:
        raise ValueError(f"Expected 3D TIFF stack (Z,Y,X). Got {vol_zyx.shape}")
    return vol_zyx.transpose(2, 1, 0)

def to_zyx(vol_xyz: np.ndarray) -> np.ndarray:
    """Convert (X,Y,Z) -> TIFF order (Z,Y,X)."""
    if vol_xyz.ndim != 3:
        raise ValueError(f"Expected 3D volume (X,Y,Z). Got {vol_xyz.shape}")
    return vol_xyz.transpose(2, 1, 0)

def pad_z_um(vol_xyz: np.ndarray, spacing_z_um: float, pad_um: float, fill=0):
    """Pad in Z by pad_um (µm) on each side. Volume is (X,Y,Z)."""
    n = int(np.round(float(pad_um) / float(spacing_z_um)))
    if n <= 0:
        return vol_xyz, 0
    vol_p = np.pad(vol_xyz, ((0, 0), (0, 0), (n, n)), mode="constant", constant_values=fill)
    return vol_p, n

def brain_mask(vol_xyz: np.ndarray, spacing_xyz: np.ndarray, lambda2: float):
    """Coarse brain mask via level_set on a downsampled volume, then upsample + smooth."""
    vol_skip = vol_xyz[::2, ::2, ::2]
    skip_spacing = spacing_xyz * np.array([2, 2, 2], dtype=float)

    mask_small = level_set.brain_detection(
        vol_skip, skip_spacing,
        mask_smoothing=2,
        iterations=[80, 40, 10],
        smooth_sigmas=[12, 6, 3],
        lambda2=lambda2,
    )

    mask = zoom(mask_small, np.array(vol_xyz.shape) / np.array(vol_skip.shape), order=0)
    mask = binary_closing(mask, np.ones((5, 5, 5))).astype(np.uint8)
    mask = binary_dilation(mask, np.ones((5, 5, 5))).astype(np.uint8)
    return mask

# %% [markdown]
# ## 1) Inputs and obvious corrections
#
# Load fixed and moving stacks, convert to **(X, Y, Z)**, and pad **±20 µm** in Z.
# Also saves padded TIFFs for QC.

# %%
# Load TIFFs (assumed Z,Y,X) -> convert to X,Y,Z
fix = to_xyz(imread(fix_path))
mov = to_xyz(imread(mov_path))

print("Original shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Pad in Z (±pad_um)
fix, fix_pad_slices = pad_z_um(fix, fix_spacing[2], pad_um, fill=0)
mov, mov_pad_slices = pad_z_um(mov, mov_spacing[2], pad_um, fill=0)

print(f"Padding applied: fix +/- {fix_pad_slices} slices, mov +/- {mov_pad_slices} slices")
print("Padded shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Save padded stacks (TIFF order Z,Y,X)
fix_padded_path = save_path("fixed_pad20um", "tif")
mov_padded_path = save_path("moving_pad20um", "tif")

imwrite(fix_padded_path, to_zyx(fix), bigtiff=True)
imwrite(mov_padded_path, to_zyx(mov), bigtiff=True)

print("[save] padded stacks:")
print("  fix:", fix_padded_path)
print("  mov:", mov_padded_path)

write_meta(
    fixed_path=str(fix_path),
    moving_path=str(mov_path),
    fix_spacing_um=list(map(float, fix_spacing)),
    mov_spacing_um=list(map(float, mov_spacing)),
    pad_um=float(pad_um),
    fix_pad_slices=int(fix_pad_slices),
    mov_pad_slices=int(mov_pad_slices),
)
# Out:
# Original shapes (X,Y,Z):
#   fix: (591, 744, 59)
#   mov: (799, 799, 56)
# Padding applied: fix +/- 20 slices, mov +/- 10 slices
# Padded shapes (X,Y,Z):
#   fix: (591, 744, 99)
#   mov: (799, 799, 76)
# [save] padded stacks:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fixed_pad20um.tif
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_moving_pad20um.tif
# [save] /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_metadata.json

# %% [markdown]
# ## 2) Foreground masks (fixed + moving)

# %%
import numpy as np
import nrrd
from scipy.ndimage import gaussian_filter, binary_fill_holes, binary_closing, binary_dilation
from skimage.filters import threshold_otsu
from skimage.measure import label

def otsu_fill_mask(vol, sigma=2, close_shape=(5,5,5), dilate_iter=64):
    # normalize
    v = vol.astype(np.float32)
    p1, p99 = np.percentile(v, (1, 99))
    v = np.clip((v - p1) / (p99 - p1 + 1e-6), 0, 1)

    # smooth
    v = gaussian_filter(v, sigma=sigma)

    # threshold
    t = threshold_otsu(v)
    m = v > t

    # keep largest CC (guard empty)
    lbl = label(m)
    if lbl.max() > 0:
        counts = np.bincount(lbl.ravel())
        counts[0] = 0
        m = lbl == counts.argmax()

    # fill + smooth + margin
    m = binary_fill_holes(m)
    m = binary_closing(m, structure=np.ones(close_shape, dtype=bool))
    m = binary_dilation(m, iterations=int(dilate_iter))

    return m.astype(np.uint8)

# --- FIX mask ---
fix_mask = otsu_fill_mask(fix, sigma=2, close_shape=(5,5,5), dilate_iter=32)
fix_mask_path = save_path("fix_mask", "nrrd")
nrrd.write(str(fix_mask_path), fix_mask)
print("  fix:", fix_mask_path)

# --- MOV mask (same strategy, homogeneous) ---
mov_mask = otsu_fill_mask(mov, sigma=2, close_shape=(5,5,5), dilate_iter=32)
mov_mask_path = save_path("mov_mask", "nrrd")
nrrd.write(str(mov_mask_path), mov_mask)
print("  mov:", mov_mask_path)
# Out:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fix_mask.nrrd
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_mov_mask.nrrd

# %% [markdown]
# ## 3) Moments initialization (modes)

# %%
fix_mean, fix_evals, fix_evecs = principal_axes(fix_mask, fix_spacing)
mov_mean, mov_evals, mov_evecs = principal_axes(mov_mask, mov_spacing)

modes = align_modes(fix_mean, fix_evecs, mov_mean, mov_evecs)

modes_aligned = apply_transform(
    fix, mov,
    fix_spacing, mov_spacing,
    transform_list=[modes],
)

np.savetxt(save_path("modes", "mat"), modes)
nrrd.write(str(save_path("modes_aligned", "nrrd")), modes_aligned, compression_level=2)

print("[save] modes:", save_path("modes", "mat"))
# Out:
# [save] modes: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_modes.mat

# %% [markdown]
# ## 4) Global alignment (rigid → affine → deform)

# %%
affine, deform = alignment_pipeline(
    fix, mov, fix_spacing, mov_spacing,
    steps=["rigid", "affine", "deform"],
    initial_transform=modes,
    alignment_spacing=2.0,
    shrink_factors=[2],
    smooth_sigmas=[8.0],
    iterations=400,
    deform_kwargs={
        "control_point_spacing": 5,
        "control_point_levels": [1, 2, 4, 8, 16, 32, 64, 128],
    },
)

# alignment_pipeline returns (affine, (params, field))
deform_field = deform[1]
    
affine_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine])
deform_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine, deform_field])

np.savetxt(save_path("affine", "mat"), affine)
nrrd.write(str(save_path("deform", "nrrd")), deform_field, compression_level=2)
nrrd.write(str(save_path("affine_aligned", "nrrd")), affine_aligned, compression_level=2)
nrrd.write(str(save_path("deform_aligned", "nrrd")), deform_aligned, compression_level=2)

print("[save] global alignment outputs under:", out_path)

import numpy as np
from tifffile import imwrite as tiff_imwrite

def _to_uint16_for_imagej(vol_zyx: np.ndarray) -> np.ndarray:
    """Convert a ZYX volume to uint16 for ImageJ overlays (robust display scaling)."""
    if np.issubdtype(vol_zyx.dtype, np.floating):
        p1, p99 = np.percentile(vol_zyx, (0.1, 99.9))
        if p99 > p1:
            v = (vol_zyx - p1) / (p99 - p1)
        else:
            v = np.clip(vol_zyx, 0, 1)
        return (np.clip(v, 0, 1) * 65535).astype(np.uint16)
    return np.clip(vol_zyx, 0, 65535).astype(np.uint16)

print(">> Building ImageJ 2-channel overlay (fixed, affine_aligned)...")

# Convert your (X,Y,Z) arrays to ImageJ-style (Z,Y,X)
fixed_zyx  = to_zyx(fix).astype(np.float32, copy=False)
warped_zyx = to_zyx(affine_aligned).astype(np.float32, copy=False)

fixed_u16  = _to_uint16_for_imagej(fixed_zyx)
warped_u16 = _to_uint16_for_imagej(warped_zyx)

# Match Z in case shapes differ slightly
zmin = min(fixed_u16.shape[0], warped_u16.shape[0])

# ImageJ hyperstack expects TZCYX; we build (T=1, Z, C=2, Y, X)
stacked = np.stack([fixed_u16[:zmin], warped_u16[:zmin]], axis=1)  # (Z, C, Y, X)
stacked = stacked[np.newaxis, ...]                                  # (T, Z, C, Y, X)

overlay_out = save_path("overlay_fixed_vs_affine", "tif")
print(f"[save] Writing overlay TIFF: {overlay_out}")
tiff_imwrite(
    str(overlay_out),
    stacked,
    bigtiff=True,
    imagej=True,
    metadata={"axes": "TZCYX"},
)
# Out:
# LEVEL:  0  ITERATION:  0  METRIC:  -0.05234340373748771
# LEVEL:  0  ITERATION:  1  METRIC:  -0.05299415335302724
# LEVEL:  0  ITERATION:  2  METRIC:  -0.05361778146567512
# LEVEL:  0  ITERATION:  3  METRIC:  -0.054523710863698074
# LEVEL:  0  ITERATION:  4  METRIC:  -0.056247273233900094
# LEVEL:  0  ITERATION:  5  METRIC:  -0.05829724947112885
# LEVEL:  0  ITERATION:  6  METRIC:  -0.05987502794449115
# LEVEL:  0  ITERATION:  7  METRIC:  -0.0630577577099808
# LEVEL:  0  ITERATION:  8  METRIC:  -0.0656669108392665
# LEVEL:  0  ITERATION:  9  METRIC:  -0.06751806503095586
# LEVEL:  0  ITERATION:  10  METRIC:  -0.07069727078713078
# LEVEL:  0  ITERATION:  11  METRIC:  -0.07369954204637708
# LEVEL:  0  ITERATION:  12  METRIC:  -0.07708072740780712
# LEVEL:  0  ITERATION:  13  METRIC:  -0.07917218957727669
# LEVEL:  0  ITERATION:  98  METRIC:  -0.6578035217309081
# LEVEL:  0  ITERATION:  99  METRIC:  -0.6586845022952416
# LEVEL:  0  ITERATION:  100  METRIC:  -0.6598843059273746
# LEVEL:  0  ITERATION:  101  METRIC:  -0.6607679514487094
# LEVEL:  0  ITERATION:  102  METRIC:  -0.6619482691444056
# LEVEL:  0  ITERATION:  103  METRIC:  -0.6627745622734786
# LEVEL:  0  ITERATION:  104  METRIC:  -0.663644400964138
# LEVEL:  0  ITERATION:  105  METRIC:  -0.6646180620186456
# LEVEL:  0  ITERATION:  106  METRIC:  -0.6654251092792027
# LEVEL:  0  ITERATION:  107  METRIC:  -0.6662295194456943
# LEVEL:  0  ITERATION:  108  METRIC:  -0.6669497458026471
# LEVEL:  0  ITERATION:  109  METRIC:  -0.6678327221271801
# LEVEL:  0  ITERATION:  110  METRIC:  -0.6685904686488633
# LEVEL:  0  ITERATION:  111  METRIC:  -0.6694220009116968
# LEVEL:  0  ITERATION:  112  METRIC:  -0.6703094338150671
# LEVEL:  0  ITERATION:  113  METRIC:  -0.6711012010670071
# LEVEL:  0  ITERATION:  114  METRIC:  -0.6719311501419164
# LEVEL:  0  ITERATION:  115  METRIC:  -0.6728545523738306
# LEVEL:  0  ITERATION:  116  METRIC:  -0.6737628816372939
# LEVEL:  0  ITERATION:  117  METRIC:  -0.6745401392059065
# LEVEL:  0  ITERATION:  118  METRIC:  -0.6752948282154111
# LEVEL:  0  ITERATION:  119  METRIC:  -0.6761012412953762
# LEVEL:  0  ITERATION:  120  METRIC:  -0.676845511110588
# LEVEL:  0  ITERATION:  121  METRIC:  -0.6776787543733186
# LEVEL:  0  ITERATION:  122  METRIC:  -0.6782533032651028
# LEVEL:  0  ITERATION:  123  METRIC:  -0.6791667829880215
# LEVEL:  0  ITERATION:  124  METRIC:  -0.6794994296755411
# LEVEL:  0  ITERATION:  125  METRIC:  -0.6807284261579815
# LEVEL:  0  ITERATION:  126  METRIC:  -0.6809931751442915
# LEVEL:  0  ITERATION:  127  METRIC:  -0.6822321815793584
# LEVEL:  0  ITERATION:  128  METRIC:  -0.6825669010890314
# LEVEL:  0  ITERATION:  129  METRIC:  -0.6836101233489379
# LEVEL:  0  ITERATION:  130  METRIC:  -0.6840125192475219
# LEVEL:  0  ITERATION:  131  METRIC:  -0.684773113414374
# LEVEL:  0  ITERATION:  132  METRIC:  -0.6852705201494748
# LEVEL:  0  ITERATION:  133  METRIC:  -0.6860341168310732
# LEVEL:  0  ITERATION:  134  METRIC:  -0.686578712565032
# LEVEL:  0  ITERATION:  135  METRIC:  -0.6872030518631548
# LEVEL:  0  ITERATION:  136  METRIC:  -0.6877586280102598
# LEVEL:  0  ITERATION:  137  METRIC:  -0.6883948212915901
# LEVEL:  0  ITERATION:  138  METRIC:  -0.689044467460163
# LEVEL:  0  ITERATION:  139  METRIC:  -0.6896891272106231
# LEVEL:  0  ITERATION:  140  METRIC:  -0.6903535389155656
# LEVEL:  0  ITERATION:  141  METRIC:  -0.690997079499048
# LEVEL:  0  ITERATION:  142  METRIC:  -0.6917034548470776
# LEVEL:  0  ITERATION:  367  METRIC:  -0.7669766554797873
# LEVEL:  0  ITERATION:  368  METRIC:  -0.7660087856519097
# LEVEL:  0  ITERATION:  369  METRIC:  -0.7673537336115348
# LEVEL:  0  ITERATION:  370  METRIC:  -0.7661760929415006
# LEVEL:  0  ITERATION:  371  METRIC:  -0.7677329621796379
# LEVEL:  0  ITERATION:  372  METRIC:  -0.7663369254094393
# LEVEL:  0  ITERATION:  373  METRIC:  -0.7680346656566979
# LEVEL:  0  ITERATION:  374  METRIC:  -0.7664822932498349
# LEVEL:  0  ITERATION:  375  METRIC:  -0.76832749041491
# LEVEL:  0  ITERATION:  376  METRIC:  -0.7669711752344789
# LEVEL:  0  ITERATION:  377  METRIC:  -0.7686472087234296
# LEVEL:  0  ITERATION:  378  METRIC:  -0.7674621498842722
# LEVEL:  0  ITERATION:  379  METRIC:  -0.7689635064662077
# LEVEL:  0  ITERATION:  380  METRIC:  -0.7679068356375567
# LEVEL:  0  ITERATION:  381  METRIC:  -0.7693251433368709
# LEVEL:  0  ITERATION:  382  METRIC:  -0.7680756525191855
# LEVEL:  0  ITERATION:  383  METRIC:  -0.7695666287382754
# LEVEL:  0  ITERATION:  384  METRIC:  -0.768493219090407
# LEVEL:  0  ITERATION:  385  METRIC:  -0.7698712745726889
# LEVEL:  0  ITERATION:  386  METRIC:  -0.7685821781705727
# LEVEL:  0  ITERATION:  387  METRIC:  -0.7701335645059344
# LEVEL:  0  ITERATION:  388  METRIC:  -0.7689874203387349
# LEVEL:  0  ITERATION:  389  METRIC:  -0.7704093628077209
# LEVEL:  0  ITERATION:  390  METRIC:  -0.7692148981511816
# LEVEL:  0  ITERATION:  391  METRIC:  -0.7707131528147139
# LEVEL:  0  ITERATION:  392  METRIC:  -0.7694664603891149
# LEVEL:  0  ITERATION:  393  METRIC:  -0.771013867326625
# LEVEL:  0  ITERATION:  394  METRIC:  -0.7696346376363937
# LEVEL:  0  ITERATION:  395  METRIC:  -0.7712649305498596
# LEVEL:  0  ITERATION:  396  METRIC:  -0.769809273170071
# LEVEL:  0  ITERATION:  397  METRIC:  -0.7715169265885676
# LEVEL:  0  ITERATION:  398  METRIC:  -0.7699415933189078
# LEVEL:  0  ITERATION:  399  METRIC:  -0.7717464058724347
# [save] global alignment outputs under: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output
# >> Building ImageJ 2-channel overlay (fixed, affine_aligned)...
# [save] Writing overlay TIFF: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_overlay_fixed_vs_affine.tif
# /Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/tifffile/tifffile.py:1739: UserWarning: <tifffile.TiffWriter 'exp_001_fish2_o…ed_vs_affine.tif'> writing nonconformant BigTIFF ImageJ
#   warnings.warn(

# %% [markdown]
# ## 5) Wiggle refinement (nested piecewise alignment)

# %%
#Very buggy step. 

block_schedule = [[150, 150, 15]] #in um. 


parameter_schedule = [
    {'random_kwargs':{'max_translation':10.,
                    'max_rotation':10. * np.pi/180.,
                    'max_scale':1.10,
                    'max_shear':.10,
                    'random_iterations':25,
                    'affine_align_best':10,
                    'alignment_spacing' : 2,
                    'iterations':24,},
    'affine_kwargs':{},
    'deform_kwargs':{},
    },
]

# run twist
wiggle = nested_distributed_piecewise_alignment_pipeline(
    fix,
    mov,
    fix_spacing,
    mov_spacing,
    block_schedule,
    parameter_schedule=parameter_schedule,
    initial_transform_list=[affine, deform_field],
    fix_mask=fix_mask,
    mov_mask=mov_mask,
    steps=['random'],
    bins=32,
    shrink_factors=[1,],
    smooth_sigmas=[6,],
    iterations=400,
    learning_rate=0.1,
    max_step=0.1,
    estimate_learning_rate='never',
    callback=lambda irm: None,
    intermediates_path=str(intermediates_path),
    cluster_kwargs={"cluster_type": "local_cluster", "n_workers": 8}
)

wiggled = apply_transform(
    fix, mov, fix_spacing, mov_spacing,
    transform_list=[affine, deform_field, wiggle],
)

nrrd.write(str(save_path("wiggle", "nrrd")), wiggle, compression_level=2)
nrrd.write(str(save_path("wiggled_aligned", "nrrd")), wiggled, compression_level=2)

print("[save] wiggle outputs:")
print("  wiggle:", save_path("wiggle", "nrrd"))
print("  wiggled:", save_path("wiggled_aligned", "nrrd"))
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa6fa539a20): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fa6fa468c30): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# 2026-02-19 11:53:29,963 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52864', name: 4, status: running, memory: 0, processing: 0>
# 2026-02-19 11:53:30,049 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52865', name: 7, status: running, memory: 0, processing: 0>
# 2026-02-19 11:53:30,076 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52866', name: 3, status: running, memory: 0, processing: 0>
# 2026-02-19 11:53:30,150 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52867', name: 2, status: running, memory: 0, processing: 0>
# 2026-02-19 11:53:30,200 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52868', name: 1, status: running, memory: 1, processing: 0>
# 2026-02-19 11:53:30,267 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52869', name: 0, status: running, memory: 1, processing: 0>
# 2026-02-19 11:53:30,292 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52870', name: 5, status: running, memory: 1, processing: 0>
# 2026-02-19 11:53:30,323 - distributed.scheduler - WARNING - Worker failed to heartbeat for 501s; attempting restart: <WorkerState 'tcp://192.168.178.81:52871', name: 6, status: running, memory: 1, processing: 0>
# 2026-02-19 11:53:31,658 - distributed.scheduler - ERROR - Removing worker 'tcp://192.168.178.81:52871' caused the cluster to lose scattered data, which can't be recovered: {'ndarray-2c65b5f6c81ec71b7a71a934e0074916'} (stimulus_id='handle-worker-cleanup-1771498411.6578948')
# 2026-02-19 11:53:31,752 - distributed.scheduler - ERROR - Removing worker 'tcp://192.168.178.81:52869' caused the cluster to lose scattered data, which can't be recovered: {'ndarray-4e5cb3146c99a27e6e028c5b91116502'} (stimulus_id='handle-worker-cleanup-1771498411.7522979')
# 2026-02-19 11:53:32,153 - distributed.scheduler - ERROR - Removing worker 'tcp://192.168.178.81:52868' caused the cluster to lose scattered data, which can't be recovered: {'ndarray-383c6a2dc15f40cbc27a50d1c453a27b'} (stimulus_id='handle-worker-cleanup-1771498412.153288')
# 2026-02-19 11:53:32,285 - distributed.scheduler - ERROR - Removing worker 'tcp://192.168.178.81:52870' caused the cluster to lose scattered data, which can't be recovered: {'ndarray-742472388a4e867cbfe1b5cd6e945913'} (stimulus_id='handle-worker-cleanup-1771498412.285555')
# 2026-02-19 11:53:33,220 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:33,333 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:33,486 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:33,765 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:33,955 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:34,163 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:34,279 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 11:53:34,520 - distributed.nanny - WARNING - Restarting worker
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2026-02-19 12:14:05,049 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53937', name: 3, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,107 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53943', name: 6, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,158 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53946', name: 1, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,184 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53949', name: 0, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,213 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53952', name: 7, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,239 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53955', name: 2, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:05,313 - distributed.scheduler - WARNING - Worker failed to heartbeat for 1043s; attempting restart: <WorkerState 'tcp://192.168.178.81:53958', name: 5, status: running, memory: 0, processing: 0>
# 2026-02-19 12:14:07,781 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:07,902 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:08,134 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:08,430 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:08,619 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:08,879 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:14:09,079 - distributed.nanny - WARNING - Restarting worker
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2026-02-19 12:51:44,557 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2060s; attempting restart: <WorkerState 'tcp://192.168.178.81:53938', name: 4, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,606 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2059s; attempting restart: <WorkerState 'tcp://192.168.178.81:56018', name: 7, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,637 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2059s; attempting restart: <WorkerState 'tcp://192.168.178.81:56019', name: 2, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,727 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2059s; attempting restart: <WorkerState 'tcp://192.168.178.81:56024', name: 5, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,804 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2059s; attempting restart: <WorkerState 'tcp://192.168.178.81:56027', name: 1, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,847 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2060s; attempting restart: <WorkerState 'tcp://192.168.178.81:56033', name: 0, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:44,911 - distributed.scheduler - WARNING - Worker failed to heartbeat for 2060s; attempting restart: <WorkerState 'tcp://192.168.178.81:56036', name: 3, status: running, memory: 0, processing: 0>
# 2026-02-19 12:51:47,052 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/utils_comm.py", line 441, in retry_operation
#     return await retry(
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/utils_comm.py", line 420, in retry
#     return await coro()
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://192.168.178.81:56046 remote=tcp://192.168.178.81:52845>: Stream is closed
# 2026-02-19 12:51:48,856 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:49,013 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:49,137 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:49,428 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:49,667 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:49,872 - distributed.nanny - WARNING - Restarting worker
# 2026-02-19 12:51:50,035 - distributed.nanny - WARNING - Restarting worker
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 6) Invert transforms + sanity check

# %%
affine_inv = np.linalg.inv(affine)
np.savetxt(save_path("affine_inv", "mat"), affine_inv)

deform_inv = invert_displacement_vector_field(deform_field, fix_spacing)
nrrd.write(str(save_path("deform_inv", "nrrd")), deform_inv, compression_level=2)

wiggle_inv = invert_displacement_vector_field(wiggle, fix_spacing)
nrrd.write(str(save_path("wiggle_inv", "nrrd")), wiggle_inv, compression_level=2)

# sanity check: warp fixed -> moving space
fix_to_mov = apply_transform(
    mov, fix, mov_spacing, fix_spacing,
    transform_list=[wiggle_inv, deform_inv, affine_inv],
    transform_spacing=fix_spacing,
)
nrrd.write(str(save_path("fix_warped_to_moving", "nrrd")), fix_to_mov, compression_level=2)

print("[save] inverse transforms + sanity warp written under:", out_path)
