# %% [markdown]
# # CircuitSeeker multimodal registration (clean)
#
# This notebook is a cleaned, end-to-end multimodal registration workflow using **CircuitSeeker**.
#
# ## Workflow
# 1. **Inputs & obvious corrections**
#    - Define a single global identifier: `run_id = "<exp_id>_fish<fish>"` for naming outputs
#    - Load fixed/moving TIFF stacks and convert axis order to **(X, Y, Z)**
#    - Pad **±20 µm** in Z (recommended)
#
# 2. **Foreground detection**
#    - Coarse brain masks for fixed and moving
#
# 3. **Moments initialization**
#    - Principal-axes alignment (`modes`)
#
# 4. **Global alignment**
#    - rigid → affine → deform (B-spline)
#
# 5. **Wiggle refinement**
#    - Nested piecewise alignment (runs locally via ClusterWrap `local_cluster`)
#
# 6. **Invert transforms + sanity check**
#    - Save inverse transforms and warp fixed → moving space
#
# ## Notes
# - **Axis order**: TIFF stacks are assumed **(Z, Y, X)** and are converted to **(X, Y, Z)** internally.
# - **Spacing units**: microns (µm), order **(X, Y, Z)**.
# - All outputs are written under `out_path` with the prefix: **`<exp_id>_fish<fish>_...`**

# %%
# Imports (clean)
from pathlib import Path
import json
import numpy as np
import nrrd

from tifffile import imread, imwrite
from scipy.ndimage import zoom, binary_closing, binary_dilation

from CircuitSeeker import level_set
from CircuitSeeker.axisalign import principal_axes, align_modes
from CircuitSeeker.align import alignment_pipeline, nested_distributed_piecewise_alignment_pipeline
from CircuitSeeker.transform import apply_transform, invert_displacement_vector_field

# %%
# =====================
# Experiment parameters
# =====================

# Global identifiers used for ALL output names
exp_id = "exp_001"     # e.g. "001" or "exp1_110425"
fish = 2           # integer

run_id = f"{exp_id}_fish{fish}"

# Spacing (µm), order: (X, Y, Z)
mov_spacing = np.array([1.0, 1.0, 2.0], dtype=float)
fix_spacing = np.array([1.1, 1.1, 1.0], dtype=float)

# Wiggle random search iterations
randomiter = 25

# Z padding (physical units)
pad_um = 20.0

# =====================
# Paths (edit these)
# =====================

mov_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/2p_stacks/"
    "2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz.tif"
)

fix_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/oct_confocal_stacks/benchmark_data/fish2/prealigned/"
    "20x_4us_1um_DAPI_GFP488_RFP594_fish2_s1_montaged_MattesMI_GCaMP_ch1.tif"
)

out_path = Path(
    "/Users/jonathanboulanger-weill/Harvard University Dropbox/"
    "Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/"
    "data/exp1_110425/CircuitSeeker_output"
)
out_path.mkdir(parents=True, exist_ok=True)

intermediates_path = out_path / "intermediates"
intermediates_path.mkdir(parents=True, exist_ok=True)

print("Fixed stack:\n", fix_path)
print("\nMoving stack:\n", mov_path)
print("\nOutput folder:\n", out_path)
# Out:
# Fixed stack:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/oct_confocal_stacks/benchmark_data/fish2/prealigned/20x_4us_1um_DAPI_GFP488_RFP594_fish2_s1_montaged_MattesMI_GCaMP_ch1.tif
#
# Moving stack:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/2p_stacks/2025-10-13_16-04-47_fish002_setup1_arena0_MW_preprocessed_data_repeat00_tile000_950nm_0_flippedxz.tif
#
# Output folder:
#  /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output

# %%
# =====================
# Helpers
# =====================

def save_path(tag: str, ext: str) -> Path:
    """Standard output path: <out_path>/<run_id>_<tag>.<ext>"""
    return out_path / f"{run_id}_{tag}.{ext}"

def write_meta(**kwargs):
    meta = dict(run_id=run_id, exp_id=exp_id, fish=int(fish), **kwargs)
    p = save_path("metadata", "json")
    with open(p, "w") as f:
        json.dump(meta, f, indent=2, sort_keys=True)
    print("[save]", p)

def to_xyz(vol_zyx: np.ndarray) -> np.ndarray:
    """Convert TIFF order (Z,Y,X) -> (X,Y,Z)."""
    if vol_zyx.ndim != 3:
        raise ValueError(f"Expected 3D TIFF stack (Z,Y,X). Got {vol_zyx.shape}")
    return vol_zyx.transpose(2, 1, 0)

def to_zyx(vol_xyz: np.ndarray) -> np.ndarray:
    """Convert (X,Y,Z) -> TIFF order (Z,Y,X)."""
    if vol_xyz.ndim != 3:
        raise ValueError(f"Expected 3D volume (X,Y,Z). Got {vol_xyz.shape}")
    return vol_xyz.transpose(2, 1, 0)

def pad_z_um(vol_xyz: np.ndarray, spacing_z_um: float, pad_um: float, fill=0):
    """Pad in Z by pad_um (µm) on each side. Volume is (X,Y,Z)."""
    n = int(np.round(float(pad_um) / float(spacing_z_um)))
    if n <= 0:
        return vol_xyz, 0
    vol_p = np.pad(vol_xyz, ((0, 0), (0, 0), (n, n)), mode="constant", constant_values=fill)
    return vol_p, n

def brain_mask(vol_xyz: np.ndarray, spacing_xyz: np.ndarray, lambda2: float):
    """Coarse brain mask via level_set on a downsampled volume, then upsample + smooth."""
    vol_skip = vol_xyz[::2, ::2, ::2]
    skip_spacing = spacing_xyz * np.array([2, 2, 2], dtype=float)

    mask_small = level_set.brain_detection(
        vol_skip, skip_spacing,
        mask_smoothing=2,
        iterations=[80, 40, 10],
        smooth_sigmas=[12, 6, 3],
        lambda2=lambda2,
    )

    mask = zoom(mask_small, np.array(vol_xyz.shape) / np.array(vol_skip.shape), order=0)
    mask = binary_closing(mask, np.ones((5, 5, 5))).astype(np.uint8)
    mask = binary_dilation(mask, np.ones((5, 5, 5))).astype(np.uint8)
    return mask

# %% [markdown]
# ## 1) Inputs and obvious corrections
#
# Load fixed and moving stacks, convert to **(X, Y, Z)**, and pad **±20 µm** in Z.
# Also saves padded TIFFs for QC.

# %%
# Load TIFFs (assumed Z,Y,X) -> convert to X,Y,Z
fix = to_xyz(imread(fix_path))
mov = to_xyz(imread(mov_path))

print("Original shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Pad in Z (±pad_um)
fix, fix_pad_slices = pad_z_um(fix, fix_spacing[2], pad_um, fill=0)
mov, mov_pad_slices = pad_z_um(mov, mov_spacing[2], pad_um, fill=0)

print(f"Padding applied: fix +/- {fix_pad_slices} slices, mov +/- {mov_pad_slices} slices")
print("Padded shapes (X,Y,Z):")
print("  fix:", fix.shape)
print("  mov:", mov.shape)

# Save padded stacks (TIFF order Z,Y,X)
fix_padded_path = save_path("fixed_pad20um", "tif")
mov_padded_path = save_path("moving_pad20um", "tif")

imwrite(fix_padded_path, to_zyx(fix), bigtiff=True)
imwrite(mov_padded_path, to_zyx(mov), bigtiff=True)

print("[save] padded stacks:")
print("  fix:", fix_padded_path)
print("  mov:", mov_padded_path)

write_meta(
    fixed_path=str(fix_path),
    moving_path=str(mov_path),
    fix_spacing_um=list(map(float, fix_spacing)),
    mov_spacing_um=list(map(float, mov_spacing)),
    pad_um=float(pad_um),
    fix_pad_slices=int(fix_pad_slices),
    mov_pad_slices=int(mov_pad_slices),
)
# Out:
# Original shapes (X,Y,Z):
#   fix: (1024, 1024, 37)
#   mov: (799, 799, 56)
# Padding applied: fix +/- 20 slices, mov +/- 10 slices
# Padded shapes (X,Y,Z):
#   fix: (1024, 1024, 77)
#   mov: (799, 799, 76)
# [save] padded stacks:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fixed_pad20um.tif
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_moving_pad20um.tif
# [save] /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_metadata.json

# %% [markdown]
# ## 2) Foreground masks (fixed + moving)

# %%
fix_mask = brain_mask(fix, fix_spacing, lambda2=32.0)
mov_mask = brain_mask(mov, mov_spacing, lambda2=64.0)

fix_mask_path = save_path("fix_mask", "nrrd")
mov_mask_path = save_path("mov_mask", "nrrd")

nrrd.write(str(fix_mask_path), fix_mask)
nrrd.write(str(mov_mask_path), mov_mask)

print("[save] masks:")
print("  fix:", fix_mask_path)
print("  mov:", mov_mask_path)
# Out:
# [save] masks:
#   fix: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_fix_mask.nrrd
#   mov: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_mov_mask.nrrd

# %% [markdown]
# ## 3) Moments initialization (modes)

# %%
fix_mean, fix_evals, fix_evecs = principal_axes(fix_mask, fix_spacing)
mov_mean, mov_evals, mov_evecs = principal_axes(mov_mask, mov_spacing)

modes = align_modes(fix_mean, fix_evecs, mov_mean, mov_evecs)

modes_aligned = apply_transform(
    fix, mov,
    fix_spacing, mov_spacing,
    transform_list=[modes],
)

np.savetxt(save_path("modes", "mat"), modes)
nrrd.write(str(save_path("modes_aligned", "nrrd")), modes_aligned, compression_level=2)

print("[save] modes:", save_path("modes", "mat"))
# Out:
# [save] modes: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_modes.mat

# %% [markdown]
# ## 4) Global alignment (rigid → affine → deform)

# %%
affine, deform = alignment_pipeline(
    fix, mov, fix_spacing, mov_spacing,
    steps=["rigid", "affine", "deform"],
    initial_transform=modes,
    alignment_spacing=2.0,
    shrink_factors=[2],
    smooth_sigmas=[2.0],
    iterations=400,
    deform_kwargs={
        "control_point_spacing": 10.0,
        "control_point_levels": [1, 2, 4, 8, 16, 32, 64],
    },
)

# alignment_pipeline returns (affine, (params, field))
deform_field = deform[1]

affine_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine])
deform_aligned = apply_transform(fix, mov, fix_spacing, mov_spacing, transform_list=[affine, deform_field])

np.savetxt(save_path("affine", "mat"), affine)
nrrd.write(str(save_path("deform", "nrrd")), deform_field, compression_level=2)
nrrd.write(str(save_path("affine_aligned", "nrrd")), affine_aligned, compression_level=2)
nrrd.write(str(save_path("deform_aligned", "nrrd")), deform_aligned, compression_level=2)

print("[save] global alignment outputs under:", out_path)
# Out:
# LEVEL:  0  ITERATION:  0  METRIC:  -0.17726983213794648
# LEVEL:  0  ITERATION:  1  METRIC:  -0.17787422987673498
# LEVEL:  0  ITERATION:  2  METRIC:  -0.17831171513719746
# LEVEL:  0  ITERATION:  3  METRIC:  -0.17867152629561708
# LEVEL:  0  ITERATION:  4  METRIC:  -0.1789376555783284
# LEVEL:  0  ITERATION:  5  METRIC:  -0.17907158765975156
# LEVEL:  0  ITERATION:  6  METRIC:  -0.1793485053423143
# LEVEL:  0  ITERATION:  7  METRIC:  -0.17949994764073604
# LEVEL:  0  ITERATION:  8  METRIC:  -0.17955921088355345
# LEVEL:  0  ITERATION:  9  METRIC:  -0.17958875364846028
# LEVEL:  0  ITERATION:  10  METRIC:  -0.17960392724896887
# LEVEL:  0  ITERATION:  11  METRIC:  -0.1796799970299679
# LEVEL:  0  ITERATION:  12  METRIC:  -0.17975728752058293
# LEVEL:  0  ITERATION:  13  METRIC:  -0.17983628866716758
# LEVEL:  0  ITERATION:  14  METRIC:  -0.179868870646079
# LEVEL:  0  ITERATION:  15  METRIC:  -0.17988743866785314
# LEVEL:  0  ITERATION:  16  METRIC:  -0.17997135725587618
# LEVEL:  0  ITERATION:  17  METRIC:  -0.1799677957553854
# LEVEL:  0  ITERATION:  18  METRIC:  -0.17996003370289976
# LEVEL:  0  ITERATION:  19  METRIC:  -0.17997812255581405
# LEVEL:  0  ITERATION:  20  METRIC:  -0.17995869392712943
# LEVEL:  0  ITERATION:  21  METRIC:  -0.17995628776932143
# LEVEL:  0  ITERATION:  22  METRIC:  -0.17999607784171423
# LEVEL:  0  ITERATION:  23  METRIC:  -0.18002341881190304
# LEVEL:  0  ITERATION:  24  METRIC:  -0.18005210780968212
# LEVEL:  0  ITERATION:  25  METRIC:  -0.18006521204445414
# LEVEL:  0  ITERATION:  26  METRIC:  -0.1801051353967867
# LEVEL:  0  ITERATION:  27  METRIC:  -0.18013399426965657
# LEVEL:  0  ITERATION:  28  METRIC:  -0.18014205709796471
# LEVEL:  0  ITERATION:  29  METRIC:  -0.1801738884818594
# LEVEL:  0  ITERATION:  30  METRIC:  -0.18022823471876012
# LEVEL:  0  ITERATION:  31  METRIC:  -0.18032458153103187
# LEVEL:  0  ITERATION:  32  METRIC:  -0.18034011454670262
# LEVEL:  0  ITERATION:  33  METRIC:  -0.18037107128095584
# LEVEL:  0  ITERATION:  34  METRIC:  -0.18043818058018826
# LEVEL:  0  ITERATION:  35  METRIC:  -0.1804694878106482
# LEVEL:  0  ITERATION:  36  METRIC:  -0.18049265957305172
# LEVEL:  0  ITERATION:  37  METRIC:  -0.1805303769350138
# LEVEL:  0  ITERATION:  38  METRIC:  -0.18055285772050036
# LEVEL:  0  ITERATION:  39  METRIC:  -0.18057245265094826
# LEVEL:  0  ITERATION:  40  METRIC:  -0.18061734087776465
# LEVEL:  0  ITERATION:  41  METRIC:  -0.1806451416383138
# LEVEL:  0  ITERATION:  42  METRIC:  -0.18066007527333078
# LEVEL:  0  ITERATION:  86  METRIC:  -0.18175953408766796
# LEVEL:  0  ITERATION:  87  METRIC:  -0.1817712205659321
# LEVEL:  0  ITERATION:  88  METRIC:  -0.18183709327428027
# LEVEL:  0  ITERATION:  89  METRIC:  -0.1818569008254901
# LEVEL:  0  ITERATION:  90  METRIC:  -0.18188650828647346
# LEVEL:  0  ITERATION:  91  METRIC:  -0.18191280953420375
# LEVEL:  0  ITERATION:  92  METRIC:  -0.18193636878997654
# LEVEL:  0  ITERATION:  93  METRIC:  -0.1819518118897759
# LEVEL:  0  ITERATION:  94  METRIC:  -0.18196640214017523
# LEVEL:  0  ITERATION:  95  METRIC:  -0.18198664592674116
# LEVEL:  0  ITERATION:  96  METRIC:  -0.18200537231254543
# LEVEL:  0  ITERATION:  97  METRIC:  -0.1820178665279859
# LEVEL:  0  ITERATION:  98  METRIC:  -0.18203406503621597
# LEVEL:  0  ITERATION:  99  METRIC:  -0.18205193111384935
# LEVEL:  0  ITERATION:  100  METRIC:  -0.1820698939752124
# LEVEL:  0  ITERATION:  101  METRIC:  -0.18209570924540822
# LEVEL:  0  ITERATION:  102  METRIC:  -0.18211113712744853
# LEVEL:  0  ITERATION:  103  METRIC:  -0.1821306264976784
# LEVEL:  0  ITERATION:  104  METRIC:  -0.1821447562695825
# LEVEL:  0  ITERATION:  105  METRIC:  -0.18216144277067242
# LEVEL:  0  ITERATION:  106  METRIC:  -0.18217385294339042
# LEVEL:  0  ITERATION:  107  METRIC:  -0.18217966994534507
# LEVEL:  0  ITERATION:  108  METRIC:  -0.1821963954589611
# LEVEL:  0  ITERATION:  109  METRIC:  -0.18220705972374257
# LEVEL:  0  ITERATION:  110  METRIC:  -0.18222279760714405
# LEVEL:  0  ITERATION:  111  METRIC:  -0.18224006295407513
# LEVEL:  0  ITERATION:  112  METRIC:  -0.18225863240123727
# LEVEL:  0  ITERATION:  113  METRIC:  -0.1822820864815328
# LEVEL:  0  ITERATION:  114  METRIC:  -0.1822925070988644
# LEVEL:  0  ITERATION:  115  METRIC:  -0.1823032657835762
# LEVEL:  0  ITERATION:  116  METRIC:  -0.18232014221264062
# LEVEL:  0  ITERATION:  117  METRIC:  -0.18233973231515577
# LEVEL:  0  ITERATION:  118  METRIC:  -0.18235174111332894
# LEVEL:  0  ITERATION:  119  METRIC:  -0.18236093542974152
# LEVEL:  0  ITERATION:  120  METRIC:  -0.18238057509313585
# LEVEL:  0  ITERATION:  121  METRIC:  -0.18239340403589988
# LEVEL:  0  ITERATION:  122  METRIC:  -0.18240859351085933
# LEVEL:  0  ITERATION:  123  METRIC:  -0.1824231942908348
# LEVEL:  0  ITERATION:  124  METRIC:  -0.1824420671243043
# LEVEL:  0  ITERATION:  125  METRIC:  -0.18245091865076563
# LEVEL:  0  ITERATION:  126  METRIC:  -0.1824658530122131
# LEVEL:  0  ITERATION:  127  METRIC:  -0.18248089897053174
# LEVEL:  0  ITERATION:  128  METRIC:  -0.18249665395998785
# LEVEL:  0  ITERATION:  215  METRIC:  -0.18335824108103374
# LEVEL:  0  ITERATION:  216  METRIC:  -0.18335677840110307
# LEVEL:  0  ITERATION:  217  METRIC:  -0.18335790292023701
# LEVEL:  0  ITERATION:  218  METRIC:  -0.1833594299257041
# LEVEL:  0  ITERATION:  219  METRIC:  -0.18338817477583355
# LEVEL:  0  ITERATION:  220  METRIC:  -0.18340908181034088
# LEVEL:  0  ITERATION:  221  METRIC:  -0.18340593264125665
# LEVEL:  0  ITERATION:  222  METRIC:  -0.18342502255689067
# LEVEL:  0  ITERATION:  223  METRIC:  -0.1834324221271979
# LEVEL:  0  ITERATION:  224  METRIC:  -0.18341906413843662
# LEVEL:  0  ITERATION:  225  METRIC:  -0.18342855340360786
# LEVEL:  0  ITERATION:  226  METRIC:  -0.1834336445694579
# LEVEL:  0  ITERATION:  227  METRIC:  -0.1834330048795335
# LEVEL:  0  ITERATION:  0  METRIC:  -0.1834651188258653
# LEVEL:  0  ITERATION:  1  METRIC:  -0.18377138330697065
# LEVEL:  0  ITERATION:  2  METRIC:  -0.18399220370197775
# LEVEL:  0  ITERATION:  3  METRIC:  -0.18419891329891086
# LEVEL:  0  ITERATION:  4  METRIC:  -0.1844782668514737
# LEVEL:  0  ITERATION:  5  METRIC:  -0.18472572090766667
# LEVEL:  0  ITERATION:  6  METRIC:  -0.18496064086279712
# LEVEL:  0  ITERATION:  7  METRIC:  -0.18510802582926902
# LEVEL:  0  ITERATION:  8  METRIC:  -0.18530914256089423
# LEVEL:  0  ITERATION:  9  METRIC:  -0.18558104094466785
# LEVEL:  0  ITERATION:  10  METRIC:  -0.18590574721981243
# LEVEL:  0  ITERATION:  11  METRIC:  -0.1861812644262871
# LEVEL:  0  ITERATION:  12  METRIC:  -0.18651344453365948
# LEVEL:  0  ITERATION:  13  METRIC:  -0.1868548772670211
# LEVEL:  0  ITERATION:  14  METRIC:  -0.18727542493721766
# LEVEL:  0  ITERATION:  15  METRIC:  -0.18770727364801373
# LEVEL:  0  ITERATION:  16  METRIC:  -0.1880188853173423
# LEVEL:  0  ITERATION:  17  METRIC:  -0.18851252606534402
# LEVEL:  0  ITERATION:  18  METRIC:  -0.18886391013905338
# LEVEL:  0  ITERATION:  19  METRIC:  -0.1893637949937329
# LEVEL:  0  ITERATION:  20  METRIC:  -0.19001817091897066
# LEVEL:  0  ITERATION:  21  METRIC:  -0.19082345546287854
# LEVEL:  0  ITERATION:  22  METRIC:  -0.19225728414109325
# LEVEL:  0  ITERATION:  23  METRIC:  -0.19471918957199233
# LEVEL:  0  ITERATION:  24  METRIC:  -0.2007437337589741
# LEVEL:  0  ITERATION:  25  METRIC:  -0.21633200465038474
# LEVEL:  0  ITERATION:  26  METRIC:  -0.24456767488446005
# LEVEL:  0  ITERATION:  27  METRIC:  -0.24625964204776762
# LEVEL:  0  ITERATION:  28  METRIC:  -0.2461803192063995
# LEVEL:  0  ITERATION:  29  METRIC:  -0.24765167843981664
# LEVEL:  0  ITERATION:  30  METRIC:  -0.24243001041943057
# LEVEL:  0  ITERATION:  31  METRIC:  -0.2529979170577252
# LEVEL:  0  ITERATION:  32  METRIC:  -0.25009805863440954
# LEVEL:  0  ITERATION:  33  METRIC:  -0.25566461465905715
# LEVEL:  0  ITERATION:  34  METRIC:  -0.2496332810281911
# LEVEL:  0  ITERATION:  35  METRIC:  -0.2609400634254314
# LEVEL:  0  ITERATION:  36  METRIC:  -0.25587473389246995
# LEVEL:  0  ITERATION:  37  METRIC:  -0.26563901420685626
# LEVEL:  0  ITERATION:  38  METRIC:  -0.2616719436865885
# LEVEL:  0  ITERATION:  39  METRIC:  -0.2678321991771268
# LEVEL:  0  ITERATION:  40  METRIC:  -0.2588538728450579
# LEVEL:  0  ITERATION:  41  METRIC:  -0.2762938634105966
# LEVEL:  0  ITERATION:  42  METRIC:  -0.27247941549944205
# LEVEL:  0  ITERATION:  43  METRIC:  -0.2751426579908379
# LEVEL:  0  ITERATION:  44  METRIC:  -0.26311361004125355
# LEVEL:  0  ITERATION:  45  METRIC:  -0.2850556107586112
# LEVEL:  0  ITERATION:  46  METRIC:  -0.28060866152892056
# LEVEL:  0  ITERATION:  47  METRIC:  -0.2808571424162255
# LEVEL:  0  ITERATION:  48  METRIC:  -0.2629661978491413
# LEVEL:  0  ITERATION:  49  METRIC:  -0.2946026056206628
# LEVEL:  0  ITERATION:  50  METRIC:  -0.2914090669220662
# LEVEL:  0  ITERATION:  51  METRIC:  -0.28789634617927956
# LEVEL:  0  ITERATION:  52  METRIC:  -0.27047749802292886
# LEVEL:  0  ITERATION:  53  METRIC:  -0.301724914508793
# LEVEL:  0  ITERATION:  54  METRIC:  -0.29605722745000623
# LEVEL:  0  ITERATION:  55  METRIC:  -0.2944055605254966
# LEVEL:  0  ITERATION:  56  METRIC:  -0.2760398516965632
# LEVEL:  0  ITERATION:  57  METRIC:  -0.3121027192634647
# LEVEL:  0  ITERATION:  58  METRIC:  -0.312853322030734
# LEVEL:  0  ITERATION:  59  METRIC:  -0.30870907850158824
# LEVEL:  0  ITERATION:  60  METRIC:  -0.2942772935864872
# LEVEL:  0  ITERATION:  61  METRIC:  -0.3198904830425222
# LEVEL:  0  ITERATION:  62  METRIC:  -0.3144073833869514
# LEVEL:  0  ITERATION:  63  METRIC:  -0.319562537838567
# LEVEL:  0  ITERATION:  64  METRIC:  -0.30623526004704144
# LEVEL:  0  ITERATION:  65  METRIC:  -0.33233067578036424
# LEVEL:  0  ITERATION:  66  METRIC:  -0.32738920156428575
# LEVEL:  0  ITERATION:  67  METRIC:  -0.3330912393938178
# LEVEL:  0  ITERATION:  68  METRIC:  -0.31246543133093463
# LEVEL:  0  ITERATION:  69  METRIC:  -0.34638997935938987
# LEVEL:  0  ITERATION:  70  METRIC:  -0.3277653873281383
# LEVEL:  0  ITERATION:  71  METRIC:  -0.3494582044545554
# LEVEL:  0  ITERATION:  72  METRIC:  -0.3137676504343525
# LEVEL:  0  ITERATION:  73  METRIC:  -0.3614945495986573
# LEVEL:  0  ITERATION:  74  METRIC:  -0.32839791879095076
# LEVEL:  0  ITERATION:  75  METRIC:  -0.3594264293580882
# LEVEL:  0  ITERATION:  76  METRIC:  -0.30626480677503604
# LEVEL:  0  ITERATION:  77  METRIC:  -0.3763874368668809
# LEVEL:  0  ITERATION:  78  METRIC:  -0.3358886251650058
# LEVEL:  0  ITERATION:  79  METRIC:  -0.36065747179380203
# LEVEL:  0  ITERATION:  0  METRIC:  -0.28435675219057427
# LEVEL:  0  ITERATION:  1  METRIC:  -0.29238715224768086
# LEVEL:  0  ITERATION:  2  METRIC:  -0.30014906827555243
# LEVEL:  0  ITERATION:  3  METRIC:  -0.3077213304715032
# LEVEL:  0  ITERATION:  4  METRIC:  -0.31502987577028435
# LEVEL:  0  ITERATION:  5  METRIC:  -0.3220570342713272
# LEVEL:  0  ITERATION:  6  METRIC:  -0.32902017156457986
# LEVEL:  0  ITERATION:  7  METRIC:  -0.3357717307215871
# LEVEL:  0  ITERATION:  8  METRIC:  -0.3422177830818752
# LEVEL:  0  ITERATION:  9  METRIC:  -0.348515827947828
# LEVEL:  0  ITERATION:  10  METRIC:  -0.3547031641747869
# LEVEL:  0  ITERATION:  11  METRIC:  -0.36053771061742346
# LEVEL:  0  ITERATION:  12  METRIC:  -0.3660085291797456
# LEVEL:  0  ITERATION:  13  METRIC:  -0.3710787104309165
# LEVEL:  0  ITERATION:  14  METRIC:  -0.37572535511866556
# LEVEL:  0  ITERATION:  15  METRIC:  -0.3799522576881731
# LEVEL:  0  ITERATION:  16  METRIC:  -0.38355102724221796
# LEVEL:  0  ITERATION:  17  METRIC:  -0.38662469511149017
# LEVEL:  0  ITERATION:  18  METRIC:  -0.3893291013608317
# LEVEL:  0  ITERATION:  19  METRIC:  -0.39168951832024107
# LEVEL:  0  ITERATION:  20  METRIC:  -0.3937327167095252
# LEVEL:  0  ITERATION:  21  METRIC:  -0.39549713838219663
# LEVEL:  0  ITERATION:  22  METRIC:  -0.3969625878795699
# LEVEL:  0  ITERATION:  23  METRIC:  -0.3982785581748521
# LEVEL:  0  ITERATION:  24  METRIC:  -0.39948516524430905
# LEVEL:  0  ITERATION:  25  METRIC:  -0.40059880822914745
# LEVEL:  0  ITERATION:  26  METRIC:  -0.40161251306405776
# LEVEL:  0  ITERATION:  27  METRIC:  -0.4026155274540729
# LEVEL:  0  ITERATION:  28  METRIC:  -0.40356944936790734
# LEVEL:  0  ITERATION:  29  METRIC:  -0.4044923279445943
# LEVEL:  0  ITERATION:  30  METRIC:  -0.40538950108571337
# LEVEL:  0  ITERATION:  31  METRIC:  -0.4062911436451946
# LEVEL:  0  ITERATION:  32  METRIC:  -0.40719342939595293
# LEVEL:  0  ITERATION:  33  METRIC:  -0.40809188973747423
# LEVEL:  0  ITERATION:  34  METRIC:  -0.4089918961579446
# LEVEL:  0  ITERATION:  35  METRIC:  -0.4098896142239613
# LEVEL:  0  ITERATION:  79  METRIC:  -0.4416372011557995
# LEVEL:  0  ITERATION:  80  METRIC:  -0.4423714191041858
# LEVEL:  0  ITERATION:  81  METRIC:  -0.4430499348574607
# LEVEL:  0  ITERATION:  82  METRIC:  -0.44372842240333893
# LEVEL:  0  ITERATION:  83  METRIC:  -0.44440788944450704
# LEVEL:  0  ITERATION:  84  METRIC:  -0.44511414279363704
# LEVEL:  0  ITERATION:  85  METRIC:  -0.4458086718337925
# LEVEL:  0  ITERATION:  86  METRIC:  -0.446496739714108
# LEVEL:  0  ITERATION:  87  METRIC:  -0.44717336196411134
# LEVEL:  0  ITERATION:  88  METRIC:  -0.4478464159977013
# LEVEL:  0  ITERATION:  89  METRIC:  -0.4485285196437653
# LEVEL:  0  ITERATION:  90  METRIC:  -0.449206126095049
# LEVEL:  0  ITERATION:  91  METRIC:  -0.44985031729690356
# LEVEL:  0  ITERATION:  92  METRIC:  -0.45046948161737554
# LEVEL:  0  ITERATION:  93  METRIC:  -0.4510857228990255
# LEVEL:  0  ITERATION:  94  METRIC:  -0.4516863841790162
# LEVEL:  0  ITERATION:  95  METRIC:  -0.4522538728092402
# LEVEL:  0  ITERATION:  96  METRIC:  -0.45278793218993035
# LEVEL:  0  ITERATION:  97  METRIC:  -0.45331169514489
# LEVEL:  0  ITERATION:  98  METRIC:  -0.4538309321322322
# LEVEL:  0  ITERATION:  99  METRIC:  -0.4543353301715292
# LEVEL:  0  ITERATION:  100  METRIC:  -0.4548344331847593
# LEVEL:  0  ITERATION:  101  METRIC:  -0.45530909807362674
# LEVEL:  0  ITERATION:  102  METRIC:  -0.4557732849915286
# LEVEL:  0  ITERATION:  103  METRIC:  -0.45622357534811586
# LEVEL:  0  ITERATION:  104  METRIC:  -0.4566408286711427
# LEVEL:  0  ITERATION:  105  METRIC:  -0.4570611803666665
# LEVEL:  0  ITERATION:  106  METRIC:  -0.457465716081142
# LEVEL:  0  ITERATION:  107  METRIC:  -0.4578668764087209
# LEVEL:  0  ITERATION:  108  METRIC:  -0.4582297476350152
# LEVEL:  0  ITERATION:  109  METRIC:  -0.4585717824617988
# LEVEL:  0  ITERATION:  110  METRIC:  -0.45890538666472297
# LEVEL:  0  ITERATION:  111  METRIC:  -0.4592194074558965
# LEVEL:  0  ITERATION:  112  METRIC:  -0.45951869538148615
# LEVEL:  0  ITERATION:  113  METRIC:  -0.4597956270474794
# LEVEL:  0  ITERATION:  114  METRIC:  -0.4600689122094806
# LEVEL:  0  ITERATION:  115  METRIC:  -0.46033284813104214
# LEVEL:  0  ITERATION:  116  METRIC:  -0.4605701151615145
# LEVEL:  0  ITERATION:  117  METRIC:  -0.46080816608887987
# LEVEL:  0  ITERATION:  118  METRIC:  -0.46103215081020127
# LEVEL:  0  ITERATION:  119  METRIC:  -0.4612289542069964
# LEVEL:  0  ITERATION:  120  METRIC:  -0.46143088951866684
# LEVEL:  0  ITERATION:  121  METRIC:  -0.461626706535743
# LEVEL:  0  ITERATION:  122  METRIC:  -0.46180794912341094
# LEVEL:  0  ITERATION:  123  METRIC:  -0.4619778901954844
# LEVEL:  0  ITERATION:  124  METRIC:  -0.4621529878642066
# LEVEL:  0  ITERATION:  125  METRIC:  -0.46232236392968507
# LEVEL:  0  ITERATION:  126  METRIC:  -0.46248387559226767
# LEVEL:  0  ITERATION:  127  METRIC:  -0.46264070795184853
# LEVEL:  0  ITERATION:  128  METRIC:  -0.4627807079659935
# LEVEL:  0  ITERATION:  129  METRIC:  -0.4629095107943294
# LEVEL:  0  ITERATION:  130  METRIC:  -0.46303683743962937
# LEVEL:  0  ITERATION:  131  METRIC:  -0.46316048984444985
# LEVEL:  0  ITERATION:  132  METRIC:  -0.4632788822120317
# LEVEL:  0  ITERATION:  133  METRIC:  -0.4633834764769774
# LEVEL:  0  ITERATION:  134  METRIC:  -0.463483523893187
# LEVEL:  0  ITERATION:  135  METRIC:  -0.4635835948186683
# LEVEL:  0  ITERATION:  136  METRIC:  -0.46368403728726454
# LEVEL:  0  ITERATION:  137  METRIC:  -0.46377389730261837
# LEVEL:  0  ITERATION:  138  METRIC:  -0.46386381998917153
# LEVEL:  0  ITERATION:  139  METRIC:  -0.463941697789262
# LEVEL:  0  ITERATION:  140  METRIC:  -0.4640221909886529
# LEVEL:  0  ITERATION:  141  METRIC:  -0.46410608210318366
# LEVEL:  0  ITERATION:  142  METRIC:  -0.46418227142640556
# LEVEL:  0  ITERATION:  143  METRIC:  -0.46424272171246467
# LEVEL:  0  ITERATION:  144  METRIC:  -0.4643058685389363
# LEVEL:  0  ITERATION:  145  METRIC:  -0.4643734860172214
# LEVEL:  0  ITERATION:  146  METRIC:  -0.4644274143861223
# LEVEL:  0  ITERATION:  147  METRIC:  -0.4644917297767665
# LEVEL:  0  ITERATION:  148  METRIC:  -0.4645552006312591
# LEVEL:  0  ITERATION:  149  METRIC:  -0.4646032109224044
# LEVEL:  0  ITERATION:  150  METRIC:  -0.46466096488765385
# LEVEL:  0  ITERATION:  151  METRIC:  -0.4647134570738784
# LEVEL:  0  ITERATION:  152  METRIC:  -0.4647415433056945
# LEVEL:  0  ITERATION:  153  METRIC:  -0.4647989360544693
# LEVEL:  0  ITERATION:  154  METRIC:  -0.4648442917769315
# LEVEL:  0  ITERATION:  155  METRIC:  -0.464895755729909
# LEVEL:  0  ITERATION:  156  METRIC:  -0.4649368692437241
# LEVEL:  0  ITERATION:  157  METRIC:  -0.4649744399350927
# LEVEL:  0  ITERATION:  158  METRIC:  -0.46500998480689576
# LEVEL:  0  ITERATION:  159  METRIC:  -0.46505255155736014
# LEVEL:  0  ITERATION:  160  METRIC:  -0.4650878300340901
# LEVEL:  0  ITERATION:  161  METRIC:  -0.46510892250637165
# LEVEL:  0  ITERATION:  162  METRIC:  -0.46514403869495874
# LEVEL:  0  ITERATION:  163  METRIC:  -0.4651634388168454
# LEVEL:  0  ITERATION:  164  METRIC:  -0.4651959790682288
# LEVEL:  0  ITERATION:  165  METRIC:  -0.4652294203375482
# LEVEL:  0  ITERATION:  166  METRIC:  -0.46526097878161293
# LEVEL:  0  ITERATION:  167  METRIC:  -0.4652992050543918
# LEVEL:  0  ITERATION:  168  METRIC:  -0.465328093726449
# LEVEL:  0  ITERATION:  169  METRIC:  -0.4653545008917012
# LEVEL:  0  ITERATION:  170  METRIC:  -0.4653801405486611
# LEVEL:  0  ITERATION:  171  METRIC:  -0.46540902961691694
# LEVEL:  0  ITERATION:  172  METRIC:  -0.4654278270333942
# LEVEL:  0  ITERATION:  173  METRIC:  -0.46543051266209357
# LEVEL:  0  ITERATION:  174  METRIC:  -0.4654591355252484
# LEVEL:  0  ITERATION:  175  METRIC:  -0.46548742955305605
# LEVEL:  0  ITERATION:  176  METRIC:  -0.46549690744968797
# LEVEL:  0  ITERATION:  177  METRIC:  -0.46551819486758644
# LEVEL:  0  ITERATION:  178  METRIC:  -0.4655328990949936
# LEVEL:  0  ITERATION:  179  METRIC:  -0.4655530381206019
# LEVEL:  0  ITERATION:  180  METRIC:  -0.4655802243539972
# LEVEL:  0  ITERATION:  181  METRIC:  -0.4656037486776721
# LEVEL:  0  ITERATION:  182  METRIC:  -0.4656346382113608
# LEVEL:  0  ITERATION:  183  METRIC:  -0.4656634195296178
# LEVEL:  0  ITERATION:  184  METRIC:  -0.46567543637314046
# LEVEL:  0  ITERATION:  185  METRIC:  -0.46570106634739916
# LEVEL:  0  ITERATION:  186  METRIC:  -0.4657259044836517
# LEVEL:  0  ITERATION:  187  METRIC:  -0.465737697344674
# LEVEL:  0  ITERATION:  188  METRIC:  -0.4657574657492151
# LEVEL:  0  ITERATION:  189  METRIC:  -0.4657743090434706
# LEVEL:  0  ITERATION:  190  METRIC:  -0.4657958872317021
# LEVEL:  0  ITERATION:  191  METRIC:  -0.4658143296835387
# LEVEL:  0  ITERATION:  192  METRIC:  -0.46583845813708885
# LEVEL:  0  ITERATION:  193  METRIC:  -0.46585460572255444
# LEVEL:  0  ITERATION:  194  METRIC:  -0.4658767279546159
# LEVEL:  0  ITERATION:  195  METRIC:  -0.4658933604231514
# LEVEL:  0  ITERATION:  196  METRIC:  -0.465904370253693
# LEVEL:  0  ITERATION:  197  METRIC:  -0.4659142170892032
# LEVEL:  0  ITERATION:  198  METRIC:  -0.4659325996059001
# LEVEL:  0  ITERATION:  199  METRIC:  -0.46592918290197993
# LEVEL:  0  ITERATION:  200  METRIC:  -0.4659426574073413
# LEVEL:  0  ITERATION:  201  METRIC:  -0.4659678486289952
# [save] global alignment outputs under: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output

# %% [markdown]
# ## 5) Wiggle refinement (nested piecewise alignment)

# %%
block_schedule = [[tuple(np.maximum(1, np.round(np.array(fix.shape) / 32).astype(int)))]]

parameter_schedule = [{
    "random_kwargs": {
        "max_translation": 10.0,
        "max_rotation": 10.0 * np.pi / 180.0,
        "max_scale": 1.10,
        "max_shear": 0.10,
        "random_iterations": int(randomiter),
        "affine_align_best": 10,
        "iterations": 24,
    },
    "affine_kwargs": {},
    'deform_kwargs':{},
}]

wiggle = nested_distributed_piecewise_alignment_pipeline(
    fix, mov, fix_spacing, mov_spacing,
    block_schedule,
    parameter_schedule=parameter_schedule,
    initial_transform_list=[affine, deform_field],
    fix_mask=fix_mask,
    mov_mask=mov_mask,
    steps=["random", "affine", "deform"],
    bins=256,
    shrink_factors=[1],
    smooth_sigmas=[6.0],
    iterations=400,
    learning_rate=0.1,
    max_step=0.1,
    estimate_learning_rate="never",
    callback=lambda irm: None,
    intermediates_path=str(intermediates_path),
    cluster_kwargs={"cluster_type": "local_cluster", "n_workers": 4},
)

wiggled = apply_transform(
    fix, mov, fix_spacing, mov_spacing,
    transform_list=[affine, deform_field, wiggle],
)

nrrd.write(str(save_path("wiggle", "nrrd")), wiggle, compression_level=2)
nrrd.write(str(save_path("wiggled_aligned", "nrrd")), wiggled, compression_level=2)

print("[save] wiggle outputs:")
print("  wiggle:", save_path("wiggle", "nrrd"))
print("  wiggled:", save_path("wiggled_aligned", "nrrd"))
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#
#
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fdb3a205cd0): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fdb605b88f0): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fdb3a205cd0): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkRecursiveSeparableImageFilter.hxx:226:
# ITK ERROR: RecursiveGaussianImageFilter(0x7fdaba7f26c0): The number of pixels along direction 0 is less than 4. This filter requires a minimum of four pixels along the dimension to be processed.
#
# Returning default
# /Users/jonathanboulanger-weill/anaconda3/envs/stx-py310/lib/python3.10/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 15.11 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# Optimization failed to improve metric
# initial value: -0.14547586555223802
# final value: -0.14464107533904086
# Returning default
# Optimization failed to improve metric
# initial value: -0.13445044394062908
# final value: -0.13429971836477728
# Returning default
# Optimization failed to improve metric
# initial value: -0.11999284095962698
# final value: -0.11915526706025525
# Returning default
# Optimization failed to improve metric
# initial value: -0.11809635379324994
# final value: -0.11661290070884052
# Returning default
# Optimization failed to improve metric
# initial value: -0.11358096430560893
# final value: -0.11216713235891511
# Returning default
# Optimization failed to improve metric
# initial value: -0.13040410052807355
# final value: -0.1303272123044762
# Returning default
# Optimization failed to improve metric
# initial value: -0.11223508296290426
# final value: -0.11153720909027341
# Returning default
# Optimization failed to improve metric
# initial value: -0.13015773044365375
# final value: -0.13014801404702694
# Returning default
# Optimization failed to improve metric
# initial value: -0.11051640187714329
# final value: -0.11045689814245337
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fa1167f1ce0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fb46f3fe150): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1670fd9b0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a396d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c057e330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b78d260): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa30bcf0830): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5f0a830): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1470e23c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7f1540): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1367ef290): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fed5f0f1460): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fed5e7e5700): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b07fb9c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5804080): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0a6823730): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb47012f8a0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7d46f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb470113130): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa30bc98eb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fecd8b3ae60): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fed5e7e5700): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1367ef290): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b07d4d10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7d46f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb47012c330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f66b9e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5b3e030): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0f6904940): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31c0eaa10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fecd8e96280): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fed7e7fc280): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a1dd30): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5d4a830): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa36b7df7a0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb52074c5d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0c501c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0ab80e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c570ab10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa36b7f2830): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa30bbc86e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1670f90f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d69e1b30): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7d1bb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c057e330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1367a65f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f57d330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b07fb9c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c07f3820): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f57d330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1167eb590): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f64ae30): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b07fb9c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7c2be0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb470113130): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c057e330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa30bc4e750): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f74ce40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31c09a850): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f3d1800): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a1dd30): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb47012dec0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c0593940): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31b7cbaa0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa31c0d7630): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa30b7d7270): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a396d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5535c00): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0afafe0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Optimization failed to improve metric
# initial value: -0.12219445421525743
# final value: -0.12206771313078417
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1670f2680): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0ab80e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a396d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f74ce40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f7490f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0a691fe80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0b726b0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa37b7f1280): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d69c5010): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1670c8fc0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5442150): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f74ce40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0c501c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa34b7e9d60): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d6a396d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1667ee390): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c570ab10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f692ce0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa33c8dfc50): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb52074c5d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d69aff80): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5512a20): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5628dc0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.13343952951015114
# final value: -0.12629639412615853
# Returning default
# Optimization failed to improve metric
# initial value: -0.11754079426223055
# final value: -0.11664798387787757
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5d5a160): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa36b7d0170): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1667cd6e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4c10a2320): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c0560530): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c054d5f0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb46f642ae0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa2c5452780): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0a68453d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1367b0b40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb4b0717610): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb47013d3d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [16.25, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0c057e330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [16.25, -2.70065e+36]
# ...
# ITK ERROR: Image(0x7f9f667ccda0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa18b8be260): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa127368d20): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9ee78159c0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa127368d20): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7feb0e753650): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb3407faa60): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f97640cf0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa14b85f5d0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9fcfbc2370): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7feb9e7de300): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa14b8901e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa14b8901e0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb3107baeb0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f975ac720): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa12750c330): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa0d67adcf0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fa19b7a8b80): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa1bb975c10): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fa14b87c930): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7febbf6ed280): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7fb3474effd0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7feb0e866660): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.13561501183086697
# final value: -0.13499557205860788
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7feb1f59a850): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fb2c0621d40): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7feb9e7d3cf0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7feb1f58a390): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.13383210781078653
# final value: -0.13222737756572014
# Returning default
# Random search failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f5768bee0): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9ee761c140): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkImageBase.hxx:90:
# ITK ERROR: Image(0x7f9f668aca40): Negative spacing is not supported and may result in undefined behavior.
# Refusing to change spacing from [1, 1] to [-2.70065e+36, -2.70065e+36]
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.12306133671148509
# final value: -0.12224977230357632
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fb30667b5c0): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Optimization failed to improve metric
# initial value: -0.1785286692391861
# final value: -0.1776396584337086
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9ee7815710): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7fb300786200): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7f9fcfbe5400): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# Registration failed due to ITK exception:
#  Exception thrown in SimpleITK ImageRegistrationMethod_MetricEvaluate: /Users/runner/work/SimpleITK/SimpleITK/bld/ITK-prefix/include/ITK-5.4/itkMattesMutualInformationImageToImageMetricv4.hxx:311:
# ITK ERROR: MattesMutualInformationImageToImageMetricv4(0x7feb9e7bf710): All samples map outside moving image buffer. The images do not sufficiently overlap. They need to be initialized to have more overlap before this metric will work. For instance, you can align the image centers by translation.
#
#
# Returning default
# [save] wiggle outputs:
#   wiggle: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_wiggle.nrrd
#   wiggled: /Users/jonathanboulanger-weill/Harvard University Dropbox/Jonathan Boulanger-Weill/Projects/calcium-spatial-transcriptomics-align/data/exp1_110425/CircuitSeeker_output/exp_001_fish2_wiggled_aligned.nrrd

# %% [markdown]
# ## 6) Invert transforms + sanity check

# %%
affine_inv = np.linalg.inv(affine)
np.savetxt(save_path("affine_inv", "mat"), affine_inv)

deform_inv = invert_displacement_vector_field(deform_field, fix_spacing)
nrrd.write(str(save_path("deform_inv", "nrrd")), deform_inv, compression_level=2)

wiggle_inv = invert_displacement_vector_field(wiggle, fix_spacing)
nrrd.write(str(save_path("wiggle_inv", "nrrd")), wiggle_inv, compression_level=2)

# sanity check: warp fixed -> moving space
fix_to_mov = apply_transform(
    mov, fix, mov_spacing, fix_spacing,
    transform_list=[wiggle_inv, deform_inv, affine_inv],
    transform_spacing=fix_spacing,
)
nrrd.write(str(save_path("fix_warped_to_moving", "nrrd")), fix_to_mov, compression_level=2)

print("[save] inverse transforms + sanity warp written under:", out_path)
